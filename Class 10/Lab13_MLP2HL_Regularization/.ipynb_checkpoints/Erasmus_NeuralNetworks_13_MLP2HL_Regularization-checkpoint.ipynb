# %% [markdown]
# # Erasmus Neural Networks
# http://michalbereta.pl/nn
# ## Multi Layer Perceptron with two hidden layers
#
# ## Basic regularization

# %% [markdown]
# ## Before you start
#
# Exacute the examples.
#
# Then, do the tasks and send back the notebook.
#
# Change the name of this notebook according to the schema: {YourSurname}\_{YourFirstName}\_{OriginalFileName}.
#
# Be sure to fill all places with "YOUR ANSWER HERE".
#
# When ready, send the notebook, with all the necessary files zipped, to the teacher.

# %% [markdown]
# ### Multi Layer Perceptron for Sofmax - two hidden layers with sigmoidal activation and regularization
#
# To use regularization, set `lmbda` to some small value, e.g., 0.001.
#
# Put the MNIST data files in the same folder before running the example.

# %%
import numpy as np

class SoftMax2HL:
    def __init__(self, inputs_num, outputs_num, hidden_num1, hidden_num2):
        self.inum = inputs_num
        self.onum = outputs_num
        self.W1 = (-1 + 2*np.random.rand(inputs_num, hidden_num1))/np.sqrt(inputs_num) #neurons as columns
        self.b1 = np.zeros((1, hidden_num1)) #horizontal vector
        self.W2 = (-1 + 2*np.random.rand(hidden_num1, hidden_num2))/np.sqrt(hidden_num1) #neurons as columns
        self.b2 = np.zeros((1, hidden_num2)) #horizontal vector
        self.W3 = (-1 + 2*np.random.rand(hidden_num2, outputs_num))/np.sqrt(hidden_num2) #neurons as columns
        self.b3 = np.zeros((1, outputs_num)) #horizontal vector
        self.probs = None
    def Forward(self, X): #examples as rows in X
        self.u1 = np.dot(X, self.W1) + self.b1
        self.hout1 = 1.0/(1.0 + np.exp(-self.u1))
        self.u2 = np.dot(self.hout1, self.W2) + self.b2
        self.hout2 = 1.0/(1.0 + np.exp(-self.u2))
        f = np.dot(self.hout2, self.W3) + self.b3
        f -= np.max(f, axis=1, keepdims=True) #trick for numerical stability
        probs = np.exp(f)
        probs /= np.sum(probs, axis=1, keepdims=True)
        self.probs = probs
    def Test(self, X, ClsIndx):
        self.Forward(X)
        #data loss: mean cross-entropy loss
        ex_num = X.shape[0]
        data_loss = -np.log(self.probs[range(ex_num),ClsIndx]).sum()/ex_num
        #classification error
        predictions = np.argmax(self.probs, axis=1)
        errors_num = np.sum(predictions != ClsIndx)
        error_rate = errors_num / ex_num
        return (data_loss, error_rate, errors_num)
    def GetProbs(self):
        return self.probs
    def GetPredictions(self):
        return np.argmax(self.probs, axis=1)
    def Learn(self, X, ClsIndx, lrate):
        self.Forward(X)
        #gradients of outputs (class probabilities)
        ex_num = X.shape[0]
        dprobs = self.probs.copy()
        dprobs[range(ex_num), ClsIndx] -= 1.0
        dprobs /= ex_num #average over all examples
        #gradient of weights and biases - output layer
        dW3 = np.dot(self.hout2.T, dprobs) # chain rule to calculate gradients
        db3 = np.sum(dprobs, axis=0,keepdims=True)
        
        #update neurons - output layer
        lmbda = 0.00 # regularization parameter
        self.W3 = self.W3 - lrate*dW3 - lmbda*self.W3
        self.b3 = self.b3 - lrate*db3 - lmbda*self.b3
        self.dW3 = dW3
        self.db3 = db3
        
        #gradient of weights and biases - 2 hidden layer
        temp = np.dot(dprobs, self.W3.T)
        du2 = self.hout2*(1 - self.hout2)
        temp = temp * du2  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW2 = np.dot(self.hout1.T, temp) # chain rule to calculate gradients
        db2 = np.sum(temp, axis=0,keepdims=True)
        #update neurons - second hidden layer
        self.W2 = self.W2 - lrate*dW2 - lmbda*self.W2
        self.b2 = self.b2 - lrate*db2 - lmbda*self.b2       
        self.dW2 = dW2
        self.db2 = db2
        
        #gradient of weights and biases - 1 hidden layer
        temp = np.dot(temp, self.W2.T)
        du1 = self.hout1*(1 - self.hout1)
        temp = temp * du1  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW1 = np.dot(X.T, temp) # chain rule to calculate gradients
        db1 = np.sum(temp, axis=0,keepdims=True)
        #update neurons - first hidden layer
        self.W1 = self.W1 - lrate*dW1 - lmbda*self.W1
        self.b1 = self.b1 - lrate*db1 - lmbda*self.b1       
        self.dW1 = dW1
        self.db1 = db1

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pickle       
        


#train data
print('reading train data...')
X = np.loadtxt('mnist_train.csv', delimiter=',')
labels = X[:,0].astype('int32') #the first column contains class labels
X = X[:,1:] #the rest of the columns are pixel values
X = X/255.0 #simple cormalization
print(X.shape)
print(labels.shape)
print()

#test data
print('reading test data...')
Xte = np.loadtxt('mnist_test.csv', delimiter=',')
labelste = Xte[:,0].astype('int32') #the first column contains class labels
Xte = Xte[:,1:] #the rest of the columns are pixel values
Xte = Xte/255.0 #simple cormalization
print(Xte.shape)
print(labelste.shape)
print()


net = SoftMax2HL(784, 10, 200, 100) #num of inputs = num of pixels; num of outputs = num of classes

#learning statistics
trloss = []
teloss = []
trerate = []
teerate = []
trerrors = []
teerrors = []

#checking the answers before training
(dloss, erate, errors) = net.Test(X, labels)
print('dloss:',dloss)
print('erate:',erate)
print('errors:',errors)
trloss.append(dloss)
trerate.append(erate)
trerrors.append(errors)

(dloss, erate, errors) = net.Test(Xte, labelste)
print('test dloss:',dloss)
print('test erate:',erate)
print('test errors:',errors)
teloss.append(dloss)
teerate.append(erate)
teerrors.append(errors)

print('starting learning...')
counter = 1
max_iters = 100
min_loss = 0.1

while True:
    etamin = 0.1
    etamax = 0.1
    eta = etamin + (1 - float(counter)/max_iters) * (etamax - etamin)
    if eta < etamin:
        eta = etamin
    net.Learn(X, labels, eta)
    (dloss, erate, errors) = net.Test(X, labels)
    print('\niteration', counter)
    print('eta',eta)
    print('dloss:',dloss)
    print('erate:',erate)
    print('errors:',errors)
    trloss.append(dloss)
    trerate.append(erate)
    trerrors.append(errors)
    #checking test data
    (dloss, erate, errors) = net.Test(Xte, labelste)
    print('test dloss:',dloss)
    print('test erate:',erate)
    print('test errors:',errors)
    teloss.append(dloss)
    teerate.append(erate)
    teerrors.append(errors)    
#    print('W1 max:',net.W1.max())
#    print('b1 max:',net.b1.max())
#    print('W2 max:',net.W2.max())
#    print('b2 max:',net.b2.max())
    counter += 1
    if dloss < min_loss:
        break
    if counter > max_iters:
        break
#    if erate < 0.005:
#        break
#    if math.isnan(dloss):
#        break
#    if counter % 1000 == 0:
#        #save
#        f = open(str(counter)+'my_softmax1hl_mnist.net','wb')
#        pickle.dump(net, f)
#        f.close()
print('learning finished')

#save
f = open('my_softmax2hl_mnist_200_100.net','wb')
pickle.dump(net, f)
f.close()

print('Minimum training error rate: ', min(trerate),' for iteration ',np.argmin(trerate))
print('Minimum testing error rate: ', min(teerate),' for iteration ',np.argmin(teerate))

plt.figure()
plt.plot(trloss, 'r', label='train')
plt.plot(teloss, 'b', label='test')
plt.title('Loss')
plt.legend()

plt.figure()
plt.plot(trerate, 'r', label='train')
plt.plot(teerate, 'b', label='test')
plt.title('Error rate')

plt.figure()
plt.plot(trerrors, 'r', label='train')
plt.plot(teerrors, 'b', label='test')
plt.title('Errors')

plt.show()
# Out:
# reading train data...
# (60000, 784)
# (60000,)
#
# reading test data...
# (10000, 784)
# (10000,)
#
# dloss: 2.3473923207329053
# erate: 0.90965
# errors: 54579
# test dloss: 2.3497600097972176
# test erate: 0.9108
# test errors: 9108
# starting learning...
#
# iteration 1
# eta 0.1
# dloss: 2.3226709019738263
# erate: 0.90965
# errors: 54579
# test dloss: 2.32435367398848
# test erate: 0.9108
# test errors: 9108
#
# iteration 2
# eta 0.1
# dloss: 2.311761653892132
# erate: 0.90965
# errors: 54579
# test dloss: 2.312953203422586
# test erate: 0.9108
# test errors: 9108
#
# iteration 3
# eta 0.1
# dloss: 2.306363065140392
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3071935455939654
# test erate: 0.8865
# test errors: 8865
#
# iteration 4
# eta 0.1
# dloss: 2.3035558208279383
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3041191081057804
# test erate: 0.8865
# test errors: 8865
#
# iteration 5
# eta 0.1
# dloss: 2.3020522901150193
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3024176037127266
# test erate: 0.8865
# test errors: 8865
#
# iteration 6
# eta 0.1
# dloss: 2.301225251130025
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.301443933494883
# test erate: 0.8865
# test errors: 8865
#
# iteration 7
# eta 0.1
# dloss: 2.3007547366433245
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3008648793987927
# test erate: 0.8865
# test errors: 8865
#
# iteration 8
# eta 0.1
# dloss: 2.3004737376664184
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.30050355571929
# test erate: 0.8865
# test errors: 8865
#
# iteration 9
# eta 0.1
# dloss: 2.300294007835981
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3002643582953133
# test erate: 0.8865
# test errors: 8865
#
# iteration 10
# eta 0.1
# dloss: 2.300168582833092
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.3000948551582514
# test erate: 0.8865
# test errors: 8865
#
# iteration 11
# eta 0.1
# dloss: 2.3000723518744355
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.299965883805291
# test erate: 0.8865
# test errors: 8865
#
# iteration 12
# eta 0.1
# dloss: 2.299991843527673
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2998609778232426
# test erate: 0.8865
# test errors: 8865
#
# iteration 13
# eta 0.1
# dloss: 2.2999198112138606
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2997706812666507
# test erate: 0.8865
# test errors: 8865
#
# iteration 14
# eta 0.1
# dloss: 2.299852347782025
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2996894597087167
# test erate: 0.8865
# test errors: 8865
#
# iteration 15
# eta 0.1
# dloss: 2.299787342085241
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2996140048586677
# test erate: 0.8865
# test errors: 8865
#
# iteration 16
# eta 0.1
# dloss: 2.299723650998698
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2995422936348247
# test erate: 0.8865
# test errors: 8865
#
# iteration 17
# eta 0.1
# dloss: 2.299660654163928
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.299473059260962
# test erate: 0.8865
# test errors: 8865
#
# iteration 18
# eta 0.1
# dloss: 2.2995980140374255
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2994054895329428
# test erate: 0.8865
# test errors: 8865
#
# iteration 19
# eta 0.1
# dloss: 2.299535546329642
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.299339051717833
# test erate: 0.8865
# test errors: 8865
#
# iteration 20
# eta 0.1
# dloss: 2.299473149924617
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.299273388955256
# test erate: 0.8865
# test errors: 8865
#
# iteration 21
# eta 0.1
# dloss: 2.299410768910481
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2992082576439543
# test erate: 0.8865
# test errors: 8865
#
# iteration 22
# eta 0.1
# dloss: 2.299348371975876
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2991434887326947
# test erate: 0.8865
# test errors: 8865
#
# iteration 23
# eta 0.1
# dloss: 2.29928594121358
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.299078963229081
# test erate: 0.8865
# test errors: 8865
#
# iteration 24
# eta 0.1
# dloss: 2.2992234660279136
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2990145963481647
# test erate: 0.8865
# test errors: 8865
#
# iteration 25
# eta 0.1
# dloss: 2.2991609398151533
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2989503270313425
# test erate: 0.8865
# test errors: 8865
#
# iteration 26
# eta 0.1
# dloss: 2.299098358152651
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298886110880757
# test erate: 0.8865
# test errors: 8865
#
# iteration 27
# eta 0.1
# dloss: 2.299035717809812
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2988219153150196
# test erate: 0.8865
# test errors: 8865
#
# iteration 28
# eta 0.1
# dloss: 2.2989730162073445
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298757716200033
# test erate: 0.8865
# test errors: 8865
#
# iteration 29
# eta 0.1
# dloss: 2.298910251121268
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298693495477938
# test erate: 0.8865
# test errors: 8865
#
# iteration 30
# eta 0.1
# dloss: 2.2988474205207177
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298629239482505
# test erate: 0.8865
# test errors: 8865
#
# iteration 31
# eta 0.1
# dloss: 2.2987845224789605
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298564937733151
# test erate: 0.8865
# test errors: 8865
#
# iteration 32
# eta 0.1
# dloss: 2.298721555124506
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2985005820664512
# test erate: 0.8865
# test errors: 8865
#
# iteration 33
# eta 0.1
# dloss: 2.2986585166142017
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2984361660078023
# test erate: 0.8865
# test errors: 8865
#
# iteration 34
# eta 0.1
# dloss: 2.2985954051183892
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2983716843152067
# test erate: 0.8865
# test errors: 8865
#
# iteration 35
# eta 0.1
# dloss: 2.2985322188126855
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298307132647102
# test erate: 0.8865
# test errors: 8865
#
# iteration 36
# eta 0.1
# dloss: 2.298468955873404
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2982425073199955
# test erate: 0.8865
# test errors: 8865
#
# iteration 37
# eta 0.1
# dloss: 2.2984056144749756
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298177805131321
# test erate: 0.8865
# test errors: 8865
#
# iteration 38
# eta 0.1
# dloss: 2.298342192788478
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2981130232297997
# test erate: 0.8865
# test errors: 8865
#
# iteration 39
# eta 0.1
# dloss: 2.2982786889807647
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.298048159020454
# test erate: 0.8865
# test errors: 8865
#
# iteration 40
# eta 0.1
# dloss: 2.298215101213931
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297983210094957
# test erate: 0.8865
# test errors: 8865
#
# iteration 41
# eta 0.1
# dloss: 2.298151427644968
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297918174180514
# test erate: 0.8865
# test errors: 8865
#
# iteration 42
# eta 0.1
# dloss: 2.29808766642551
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2978530491023172
# test erate: 0.8865
# test errors: 8865
#
# iteration 43
# eta 0.1
# dloss: 2.298023815701646
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.29778783275595
# test erate: 0.8865
# test errors: 8865
#
# iteration 44
# eta 0.1
# dloss: 2.297959873613757
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297722523087085
# test erate: 0.8865
# test errors: 8865
#
# iteration 45
# eta 0.1
# dloss: 2.2978958382963692
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2976571180765406
# test erate: 0.8865
# test errors: 8865
#
# iteration 46
# eta 0.1
# dloss: 2.297831707878022
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.29759161572926
# test erate: 0.8865
# test errors: 8865
#
# iteration 47
# eta 0.1
# dloss: 2.29776748048113
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297526014066183
# test erate: 0.8865
# test errors: 8865
#
# iteration 48
# eta 0.1
# dloss: 2.29770315422186
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2974603111182272
# test erate: 0.8865
# test errors: 8865
#
# iteration 49
# eta 0.1
# dloss: 2.29763872721
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2973945049218347
# test erate: 0.8865
# test errors: 8865
#
# iteration 50
# eta 0.1
# dloss: 2.29757419754883
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297328593515659
# test erate: 0.8865
# test errors: 8865
#
# iteration 51
# eta 0.1
# dloss: 2.297509563334995
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297262574938091
# test erate: 0.8865
# test errors: 8865
#
# iteration 52
# eta 0.1
# dloss: 2.297444822658378
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2971964472254083
# test erate: 0.8865
# test errors: 8865
# iteration 53
# eta 0.1
# dloss: 2.297379973601965
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.297130208410369
# test erate: 0.8865
# test errors: 8865
#
# iteration 54
# eta 0.1
# dloss: 2.2973150142417222
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2970638565211514
# test erate: 0.8865
# test errors: 8865
#
# iteration 55
# eta 0.1
# dloss: 2.297249942646459
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2969973895805276
# test erate: 0.8865
# test errors: 8865
#
# iteration 56
# eta 0.1
# dloss: 2.2971847568776993
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296930805605229
# test erate: 0.8865
# test errors: 8865
#
# iteration 57
# eta 0.1
# dloss: 2.2971194549895495
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2968641026054306
# test erate: 0.8865
# test errors: 8865
#
# iteration 58
# eta 0.1
# dloss: 2.2970540350285624
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296797278584347
# test erate: 0.8865
# test errors: 8865
#
# iteration 59
# eta 0.1
# dloss: 2.296988495033608
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.29673033153789
# test erate: 0.8865
# test errors: 8865
#
# iteration 60
# eta 0.1
# dloss: 2.296922833035733
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2966632594543803
# test erate: 0.8865
# test errors: 8865
#
# iteration 61
# eta 0.1
# dloss: 2.296857047058028
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2965960603143
# test erate: 0.8865
# test errors: 8865
#
# iteration 62
# eta 0.1
# dloss: 2.2967911351154906
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296528732090073
# test erate: 0.8865
# test errors: 8865
#
# iteration 63
# eta 0.1
# dloss: 2.2967250952148874
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296461272745863
# test erate: 0.8865
# test errors: 8865
#
# iteration 64
# eta 0.1
# dloss: 2.296658925354615
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296393680237387
# test erate: 0.8865
# test errors: 8865
#
# iteration 65
# eta 0.1
# dloss: 2.2965926235245617
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296325952511743
# test erate: 0.8865
# test errors: 8865
#
# iteration 66
# eta 0.1
# dloss: 2.296526187705964
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296258087507239
# test erate: 0.8865
# test errors: 8865
#
# iteration 67
# eta 0.1
# dloss: 2.2964596158712687
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296190083153233
# test erate: 0.8865
# test errors: 8865
#
# iteration 68
# eta 0.1
# dloss: 2.296392905983987
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.296121937369973
# test erate: 0.8865
# test errors: 8865
#
# iteration 69
# eta 0.1
# dloss: 2.296326055998555
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2960536480684417
# test erate: 0.8865
# test errors: 8865
#
# iteration 70
# eta 0.1
# dloss: 2.2962590638601847
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2959852131502014
# test erate: 0.8865
# test errors: 8865
#
# iteration 71
# eta 0.1
# dloss: 2.29619192750472
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295916630507238
# test erate: 0.8865
# test errors: 8865
#
# iteration 72
# eta 0.1
# dloss: 2.296124644858493
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2958478980218096
# test erate: 0.8865
# test errors: 8865
#
# iteration 73
# eta 0.1
# dloss: 2.296057213838169
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2957790135662925
# test erate: 0.8865
# test errors: 8865
#
# iteration 74
# eta 0.1
# dloss: 2.2959896323506053
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2957099750030245
# test erate: 0.8865
# test errors: 8865
#
# iteration 75
# eta 0.1
# dloss: 2.2959218982926957
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295640780184152
# test erate: 0.8865
# test errors: 8865
#
# iteration 76
# eta 0.1
# dloss: 2.2958540095512223
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2955714269514735
# test erate: 0.8865
# test errors: 8865
#
# iteration 77
# eta 0.1
# dloss: 2.2957859640027007
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2955019131362833
# test erate: 0.8865
# test errors: 8865
#
# iteration 78
# eta 0.1
# dloss: 2.2957177595132303
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295432236559213
# test erate: 0.8865
# test errors: 8865
#
# iteration 79
# eta 0.1
# dloss: 2.2956493939383322
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295362395030076
# test erate: 0.8865
# test errors: 8865
#
# iteration 80
# eta 0.1
# dloss: 2.2955808651228007
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2952923863477017
# test erate: 0.8865
# test errors: 8865
#
# iteration 81
# eta 0.1
# dloss: 2.2955121709005417
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2952222082997804
# test erate: 0.8865
# test errors: 8865
#
# iteration 82
# eta 0.1
# dloss: 2.2954433090944164
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295151858662696
# test erate: 0.8865
# test errors: 8865
#
# iteration 83
# eta 0.1
# dloss: 2.2953742775160775
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.29508133520137
# test erate: 0.8865
# test errors: 8865
#
# iteration 84
# eta 0.1
# dloss: 2.295305073965814
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.295010635669085
# test erate: 0.8865
# test errors: 8865
#
# iteration 85
# eta 0.1
# dloss: 2.295235696232382
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2949397578073296
# test erate: 0.8865
# test errors: 8865
#
# iteration 86
# eta 0.1
# dloss: 2.295166142092846
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2948686993456264
# test erate: 0.8865
# test errors: 8865
#
# iteration 87
# eta 0.1
# dloss: 2.295096409312412
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2947974580013595
# test erate: 0.8865
# test errors: 8865
#
# iteration 88
# eta 0.1
# dloss: 2.2950264956442585
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2947260314796125
# test erate: 0.8865
# test errors: 8865
#
# iteration 89
# eta 0.1
# dloss: 2.2949563988293704
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2946544174729873
# test erate: 0.8865
# test errors: 8865
#
# iteration 90
# eta 0.1
# dloss: 2.294886116596372
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.294582613661437
# test erate: 0.8865
# test errors: 8865
#
# iteration 91
# eta 0.1
# dloss: 2.2948156466613496
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.294510617712091
# test erate: 0.8865
# test errors: 8865
#
# iteration 92
# eta 0.1
# dloss: 2.2947449867276846
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2944384272790748
# test erate: 0.8865
# test errors: 8865
#
# iteration 93
# eta 0.1
# dloss: 2.294674134485877
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2943660400033354
# test erate: 0.8865
# test errors: 8865
#
# iteration 94
# eta 0.1
# dloss: 2.2946030876133707
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2942934535124597
# test erate: 0.8865
# test errors: 8865
#
# iteration 95
# eta 0.1
# dloss: 2.294531843774375
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.294220665420497
# test erate: 0.8865
# test errors: 8865
#
# iteration 96
# eta 0.1
# dloss: 2.2944604006196863
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.294147673327772
# test erate: 0.8865
# test errors: 8865
#
# iteration 97
# eta 0.1
# dloss: 2.2943887557865095
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.294074474820702
# test erate: 0.8865
# test errors: 8865
#
# iteration 98
# eta 0.1
# dloss: 2.294316906898276
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2940010674716134
# test erate: 0.8865
# test errors: 8865
#
# iteration 99
# eta 0.1
# dloss: 2.2942448515644545
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2939274488385504
# test erate: 0.8865
# test errors: 8865
#
# iteration 100
# eta 0.1
# dloss: 2.2941725873803738
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2938536164650887
# test erate: 0.8865
# test errors: 8865
#
# iteration 101
# eta 0.1
# dloss: 2.29410011192703
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293779567880142
# test erate: 0.8865
# test errors: 8865
#
# iteration 102
# eta 0.1
# dloss: 2.2940274227709008
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293705300597769
# test erate: 0.8865
# test errors: 8865
#
# iteration 103
# eta 0.1
# dloss: 2.2939545174637543
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293630812116983
# test erate: 0.8865
# test errors: 8865
#
# iteration 104
# eta 0.1
# dloss: 2.2938813935424536
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293556099921548
# test erate: 0.8865
# test errors: 8865
#
# iteration 105
# eta 0.1
# dloss: 2.2938080485287693
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2934811614797885
# test erate: 0.8865
# test errors: 8865
# iteration 106
# eta 0.1
# dloss: 2.293734479929177
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2934059942443827
# test erate: 0.8865
# test errors: 8865
#
# iteration 107
# eta 0.1
# dloss: 2.293660685234663
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2933305956521632
# test erate: 0.8865
# test errors: 8865
#
# iteration 108
# eta 0.1
# dloss: 2.2935866619205236
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293254963123914
# test erate: 0.8865
# test errors: 8865
#
# iteration 109
# eta 0.1
# dloss: 2.293512407446165
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293179094064163
# test erate: 0.8865
# test errors: 8865
#
# iteration 110
# eta 0.1
# dloss: 2.293437919254897
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.293102985860972
# test erate: 0.8865
# test errors: 8865
#
# iteration 111
# eta 0.1
# dloss: 2.293363194773729
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2930266358857305
# test erate: 0.8865
# test errors: 8865
#
# iteration 112
# eta 0.1
# dloss: 2.293288231413163
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.292950041492942
# test erate: 0.8865
# test errors: 8865
#
# iteration 113
# eta 0.1
# dloss: 2.2932130265669834
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.292873200020008
# test erate: 0.8865
# test errors: 8865
#
# iteration 114
# eta 0.1
# dloss: 2.293137577612044
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.292796108787015
# test erate: 0.8865
# test errors: 8865
#
# iteration 115
# eta 0.1
# dloss: 2.293061881908059
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2927187650965144
# test erate: 0.8865
# test errors: 8865
#
# iteration 116
# eta 0.1
# dloss: 2.2929859367973804
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2926411662333015
# test erate: 0.8865
# test errors: 8865
#
# iteration 117
# eta 0.1
# dloss: 2.292909739604785
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2925633094641924
# test erate: 0.8865
# test errors: 8865
#
# iteration 118
# eta 0.1
# dloss: 2.2928332876372526
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2924851920378004
# test erate: 0.8865
# test errors: 8865
#
# iteration 119
# eta 0.1
# dloss: 2.292756578183744
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2924068111843097
# test erate: 0.8865
# test errors: 8865
#
# iteration 120
# eta 0.1
# dloss: 2.292679608514975
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2923281641152404
# test erate: 0.8865
# test errors: 8865
#
# iteration 121
# eta 0.1
# dloss: 2.292602375883191
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2922492480232233
# test erate: 0.8865
# test errors: 8865
#
# iteration 122
# eta 0.1
# dloss: 2.2925248775219385
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.292170060081763
# test erate: 0.8865
# test errors: 8865
#
# iteration 123
# eta 0.1
# dloss: 2.292447110645831
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2920905974449988
# test erate: 0.8865
# test errors: 8865
#
# iteration 124
# eta 0.1
# dloss: 2.2923690724503163
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2920108572474676
# test erate: 0.8865
# test errors: 8865
#
# iteration 125
# eta 0.1
# dloss: 2.2922907601114413
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.291930836603864
# test erate: 0.8865
# test errors: 8865
#
# iteration 126
# eta 0.1
# dloss: 2.2922121707856102
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.291850532608795
# test erate: 0.8865
# test errors: 8865
#
# iteration 127
# eta 0.1
# dloss: 2.2921333016093475
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.291769942336531
# test erate: 0.8865
# test errors: 8865
#
# iteration 128
# eta 0.1
# dloss: 2.2920541496990507
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2916890628407587
# test erate: 0.8865
# test errors: 8865
#
# iteration 129
# eta 0.1
# dloss: 2.2919747121507448
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2916078911543303
# test erate: 0.8865
# test errors: 8865
#
# iteration 130
# eta 0.1
# dloss: 2.2918949860398334
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2915264242890085
# test erate: 0.8865
# test errors: 8865
#
# iteration 131
# eta 0.1
# dloss: 2.291814968420848
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.291444659235207
# test erate: 0.8865
# test errors: 8865
#
# iteration 132
# eta 0.1
# dloss: 2.2917346563271934
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2913625929617343
# test erate: 0.8865
# test errors: 8865
#
# iteration 133
# eta 0.1
# dloss: 2.2916540467708892
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.291280222415527
# test erate: 0.8865
# test errors: 8865
#
# iteration 134
# eta 0.1
# dloss: 2.2915731367423136
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2911975445213897
# test erate: 0.8865
# test errors: 8865
#
# iteration 135
# eta 0.1
# dloss: 2.2914919232099358
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2911145561817206
# test erate: 0.8865
# test errors: 8865
#
# iteration 136
# eta 0.1
# dloss: 2.2914104031200564
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2910312542762457
# test erate: 0.8865
# test errors: 8865
#
# iteration 137
# eta 0.1
# dloss: 2.2913285733965347
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2909476356617424
# test erate: 0.8865
# test errors: 8865
#
# iteration 138
# eta 0.1
# dloss: 2.2912464309405216
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2908636971717615
# test erate: 0.8865
# test errors: 8865
#
# iteration 139
# eta 0.1
# dloss: 2.291163972630181
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2907794356163484
# test erate: 0.8865
# test errors: 8865
#
# iteration 140
# eta 0.1
# dloss: 2.291081195320419
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.290694847781763
# test erate: 0.8865
# test errors: 8865
#
# iteration 141
# eta 0.1
# dloss: 2.290998095842597
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.290609930430186
# test erate: 0.8865
# test errors: 8865
#
# iteration 142
# eta 0.1
# dloss: 2.290914671004255
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2905246802994377
# test erate: 0.8865
# test errors: 8865
#
# iteration 143
# eta 0.1
# dloss: 2.290830917588821
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2904390941026818
# test erate: 0.8865
# test errors: 8865
#
# iteration 144
# eta 0.1
# dloss: 2.2907468323553246
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.290353168528129
# test erate: 0.8865
# test errors: 8865
#
# iteration 145
# eta 0.1
# dloss: 2.290662412038104
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2902669002387395
# test erate: 0.8865
# test errors: 8865
#
# iteration 146
# eta 0.1
# dloss: 2.2905776533465074
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.290180285871921
# test erate: 0.8865
# test errors: 8865
#
# iteration 147
# eta 0.1
# dloss: 2.290492552964599
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2900933220392234
# test erate: 0.8865
# test errors: 8865
#
# iteration 148
# eta 0.1
# dloss: 2.2904071075508527
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.290006005326027
# test erate: 0.8865
# test errors: 8865
#
# iteration 149
# eta 0.1
# dloss: 2.290321313737849
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2899183322912355
# test erate: 0.8865
# test errors: 8865
#
# iteration 150
# eta 0.1
# dloss: 2.290235168131964
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.289830299466952
# test erate: 0.8865
# test errors: 8865
#
# iteration 151
# eta 0.1
# dloss: 2.2901486673130584
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.28974190335817
# test erate: 0.8865
# test errors: 8865
#
# iteration 152
# eta 0.1
# dloss: 2.2900618078341615
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2896531404424407
# test erate: 0.8865
# test errors: 8865
#
# iteration 153
# eta 0.1
# dloss: 2.2899745862211494
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2895640071695516
# test erate: 0.8865
# test errors: 8865
#
# iteration 154
# eta 0.1
# dloss: 2.289886998972425
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2894744999611967
# test erate: 0.8865
# test errors: 8865
#
# iteration 155
# eta 0.1
# dloss: 2.2897990425585872
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2893846152106367
# test erate: 0.8865
# test errors: 8865
#
# iteration 156
# eta 0.1
# dloss: 2.289710713422105
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.289294349282369
# test erate: 0.8865
# test errors: 8865
#
# iteration 157
# eta 0.1
# dloss: 2.2896220079769805
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.28920369851178
# test erate: 0.8865
# test errors: 8865
#
# iteration 158
# eta 0.1
# dloss: 2.2895329226084082
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.289112659204802
# test erate: 0.8865
# test errors: 8865
#
# iteration 159
# eta 0.1
# dloss: 2.2894434536724386
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.289021227637562
# test erate: 0.8865
# test errors: 8865
#
# iteration 160
# eta 0.1
# dloss: 2.2893535974956287
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2889294000560287
# test erate: 0.8865
# test errors: 8865
#
# iteration 161
# eta 0.1
# dloss: 2.2892633503746915
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.288837172675658
# test erate: 0.8865
# test errors: 8865
#
# iteration 162
# eta 0.1
# dloss: 2.289172708576144
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.288744541681025
# test erate: 0.8865
# test errors: 8865
#
# iteration 163
# eta 0.1
# dloss: 2.2890816683359483
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2886515032254624
# test erate: 0.8865
# test errors: 8865
#
# iteration 164
# eta 0.1
# dloss: 2.2889902258591484
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2885580534306906
# test erate: 0.8865
# test errors: 8865
#
# iteration 165
# eta 0.1
# dloss: 2.288898377319506
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2884641883864383
# test erate: 0.8865
# test errors: 8865
#
# iteration 166
# eta 0.1
# dloss: 2.2888061188591267
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.28836990415007
# test erate: 0.8865
# test errors: 8865
#
# iteration 167
# eta 0.1
# dloss: 2.288713446588088
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2882751967461985
# test erate: 0.8865
# test errors: 8865
#
# iteration 168
# eta 0.1
# dloss: 2.288620356584058
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2881800621662967
# test erate: 0.8865
# test errors: 8865
#
# iteration 169
# eta 0.1
# dloss: 2.288526844891912
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2880844963683087
# test erate: 0.8865
# test errors: 8865
#
# iteration 170
# eta 0.1
# dloss: 2.2884329075233447
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.28798849527625
# test erate: 0.8865
# test errors: 8865
#
# iteration 171
# eta 0.1
# dloss: 2.2883385404564773
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.287892054779807
# test erate: 0.8865
# test errors: 8865
#
# iteration 172
# eta 0.1
# dloss: 2.2882437396354565
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2877951707339297
# test erate: 0.8865
# test errors: 8865
#
# iteration 173
# eta 0.1
# dloss: 2.288148500970058
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.287697838958421
# test erate: 0.8865
# test errors: 8865
#
# iteration 174
# eta 0.1
# dloss: 2.2880528203352757
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2876000552375215
# test erate: 0.8865
# test errors: 8865
#
# iteration 175
# eta 0.1
# dloss: 2.2879566935709086
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2875018153194864
# test erate: 0.8865
# test errors: 8865
#
# iteration 176
# eta 0.1
# dloss: 2.287860116481149
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2874031149161618
# test erate: 0.8865
# test errors: 8865
#
# iteration 177
# eta 0.1
# dloss: 2.2877630848341575
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2873039497025514
# test erate: 0.8865
# test errors: 8865
#
# iteration 178
# eta 0.1
# dloss: 2.2876655943616324
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2872043153163837
# test erate: 0.8865
# test errors: 8865
#
# iteration 179
# eta 0.1
# dloss: 2.287567640758387
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.287104207357666
# test erate: 0.8865
# test errors: 8865
#
# iteration 180
# eta 0.1
# dloss: 2.287469219681905
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.287003621388242
# test erate: 0.8865
# test errors: 8865
#
# iteration 181
# eta 0.1
# dloss: 2.2873703267518994
# erate: 0.8876333333333334
# errors: 53258
# test dloss: 2.2869025529313345
# test erate: 0.8865
# test errors: 8865
#
# iteration 182
# eta 0.1
# dloss: 2.2872709575498686
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.286800997471095
# test erate: 0.8865
# test errors: 8865
#
# iteration 183
# eta 0.1
# dloss: 2.2871711076186387
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.2866989504521333
# test erate: 0.8865
# test errors: 8865
#
# iteration 184
# eta 0.1
# dloss: 2.287070772461909
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.2865964072790543
# test erate: 0.8865
# test errors: 8865
#
# iteration 185
# eta 0.1
# dloss: 2.2869699475437835
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.286493363315981
# test erate: 0.8865
# test errors: 8865
#
# iteration 186
# eta 0.1
# dloss: 2.286868628288305
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.286389813886074
# test erate: 0.8865
# test errors: 8865
#
# iteration 187
# eta 0.1
# dloss: 2.2867668100789786
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.286285754271048
# test erate: 0.8865
# test errors: 8865
#
# iteration 188
# eta 0.1
# dloss: 2.28666448825829
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.2861811797106775
# test erate: 0.8865
# test errors: 8865
#
# iteration 189
# eta 0.1
# dloss: 2.2865616581272183
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.286076085402301
# test erate: 0.8865
# test errors: 8865
#
# iteration 190
# eta 0.1
# dloss: 2.286458314944744
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.285970466500315
# test erate: 0.8865
# test errors: 8865
#
# iteration 191
# eta 0.1
# dloss: 2.286354453927349
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.2858643181156664
# test erate: 0.8865
# test errors: 8865
#
# iteration 192
# eta 0.1
# dloss: 2.2862500702485127
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.285757635315333
# test erate: 0.8865
# test errors: 8865
#
# iteration 193
# eta 0.1
# dloss: 2.286145159038198
# erate: 0.8876166666666667
# errors: 53257
# test dloss: 2.2856504131218056
# test erate: 0.8865
# test errors: 8865
#
# iteration 194
# eta 0.1
# dloss: 2.2860397153823384
# erate: 0.8876
# errors: 53256
# test dloss: 2.285542646512553
# test erate: 0.8865
# test errors: 8865
#
# iteration 195
# eta 0.1
# dloss: 2.2859337343223074
# erate: 0.8876
# errors: 53256
# test dloss: 2.285434330419492
# test erate: 0.8865
# test errors: 8865
#
# iteration 196
# eta 0.1
# dloss: 2.2858272108543947
# erate: 0.8876
# errors: 53256
# test dloss: 2.285325459728442
# test erate: 0.8865
# test errors: 8865
#
# iteration 197
# eta 0.1
# dloss: 2.2857201399292646
# erate: 0.8876
# errors: 53256
# test dloss: 2.285216029278575
# test erate: 0.8865
# test errors: 8865
#
# iteration 198
# eta 0.1
# dloss: 2.2856125164514145
# erate: 0.8876
# errors: 53256
# test dloss: 2.2851060338618656
# test erate: 0.8865
# test errors: 8865
#
# iteration 199
# eta 0.1
# dloss: 2.285504335278625
# erate: 0.8875833333333333
# errors: 53255
# test dloss: 2.284995468222521
# test erate: 0.8865
# test errors: 8865
#
# iteration 200
# eta 0.1
# dloss: 2.285395591221399
# erate: 0.8875833333333333
# errors: 53255
# test dloss: 2.284884327056417
# test erate: 0.8864
# test errors: 8864
#
# iteration 201
# eta 0.1
# dloss: 2.285286279042402
# erate: 0.88755
# errors: 53253
# test dloss: 2.2847726050105193
# test erate: 0.8864
# test errors: 8864
#
# iteration 202
# eta 0.1
# dloss: 2.2851763934558886
# erate: 0.88755
# errors: 53253
# test dloss: 2.2846602966822998
# test erate: 0.8864
# test errors: 8864
#
# iteration 203
# eta 0.1
# dloss: 2.285065929127125
# erate: 0.88755
# errors: 53253
# test dloss: 2.284547396619146
# test erate: 0.8864
# test errors: 8864
#
# iteration 204
# eta 0.1
# dloss: 2.284954880671802
# erate: 0.8875333333333333
# errors: 53252
# test dloss: 2.2844338993177606
# test erate: 0.8864
# test errors: 8864
#
# iteration 205
# eta 0.1
# dloss: 2.2848432426554446
# erate: 0.8875166666666666
# errors: 53251
# test dloss: 2.284319799223561
# test erate: 0.8864
# test errors: 8864
#
# iteration 206
# eta 0.1
# dloss: 2.2847310095928095
# erate: 0.8874833333333333
# errors: 53249
# test dloss: 2.284205090730057
# test erate: 0.8864
# test errors: 8864
#
# iteration 207
# eta 0.1
# dloss: 2.2846181759472777
# erate: 0.8874666666666666
# errors: 53248
# test dloss: 2.2840897681782373
# test erate: 0.8864
# test errors: 8864
#
# iteration 208
# eta 0.1
# dloss: 2.2845047361302386
# erate: 0.8874333333333333
# errors: 53246
# test dloss: 2.2839738258559383
# test erate: 0.8864
# test errors: 8864
#
# iteration 209
# eta 0.1
# dloss: 2.2843906845004716
# erate: 0.8874333333333333
# errors: 53246
# test dloss: 2.2838572579972056
# test erate: 0.8864
# test errors: 8864
#
# iteration 210
# eta 0.1
# dloss: 2.2842760153635067
# erate: 0.8874166666666666
# errors: 53245
# test dloss: 2.283740058781649
# test erate: 0.8864
# test errors: 8864
#
# iteration 211
# eta 0.1
# dloss: 2.2841607229709915
# erate: 0.8873833333333333
# errors: 53243
# test dloss: 2.283622222333793
# test erate: 0.8864
# test errors: 8864
# iteration 212
# eta 0.1
# dloss: 2.2840448015200425
# erate: 0.8873833333333333
# errors: 53243
# test dloss: 2.2835037427224103
# test erate: 0.8864
# test errors: 8864
#
# iteration 213
# eta 0.1
# dloss: 2.2839282451525897
# erate: 0.8873833333333333
# errors: 53243
# test dloss: 2.2833846139598553
# test erate: 0.8864
# test errors: 8864
#
# iteration 214
# eta 0.1
# dloss: 2.2838110479547127
# erate: 0.8873666666666666
# errors: 53242
# test dloss: 2.2832648300013867
# test erate: 0.8864
# test errors: 8864
#
# iteration 215
# eta 0.1
# dloss: 2.2836932039559703
# erate: 0.8873333333333333
# errors: 53240
# test dloss: 2.2831443847444786
# test erate: 0.8864
# test errors: 8864
#
# iteration 216
# eta 0.1
# dloss: 2.2835747071287167
# erate: 0.8873
# errors: 53238
# test dloss: 2.2830232720281254
# test erate: 0.8863
# test errors: 8863
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-74fa5119a186> in <module>
#      65     if eta < etamin:
#      66         eta = etamin
# ---> 67     net.Learn(X, labels, eta)
#      68     (dloss, erate, errors) = net.Test(X, labels)
#      69     print('\niteration', counter)
#
# <ipython-input-1-ec9cb70ad4ce> in Learn(self, X, ClsIndx, lrate)
#      37         return np.argmax(self.probs, axis=1)
#      38     def Learn(self, X, ClsIndx, lrate):
# ---> 39         self.Forward(X)
#      40         #gradients of outputs (class probabilities)
#      41         ex_num = X.shape[0]
#
# <ipython-input-1-ec9cb70ad4ce> in Forward(self, X)
#      13         self.probs = None
#      14     def Forward(self, X): #examples as rows in X
# ---> 15         self.u1 = np.dot(X, self.W1) + self.b1
#      16         self.hout1 = 1.0/(1.0 + np.exp(-self.u1))
#      17         self.u2 = np.dot(self.hout1, self.W2) + self.b2
#
# KeyboardInterrupt:
