# %% [markdown]
# # Erasmus Neural Networks
# http://michalbereta.pl/nn
#
# ## CIFAR10

# %% [markdown]
# ## Before you start
#
# Exacute the examples.
#
# Then, do the tasks and send back the notebook.
#
# Change the name of this notebook according to the schema: {YourSurname}\_{YourFirstName}\_{OriginalFileName}.
#
# Be sure to fill all places with "YOUR ANSWER HERE".
#
# When ready, send the notebook, with all the necessary files zipped, to the teacher.

# %% [markdown]
# ### CIFAR10 dataset
#
# More info:  https://www.cs.toronto.edu/~kriz/cifar.html
#
# Download:  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#
# Extract the archive to your folder.

# %% [markdown]
# ## Some utility functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

def load_batch(path):
    with open(path, 'rb') as f:
        d = pickle.load(f, encoding='bytes')
    return d

def get_cifar10_train(path):
    temp = load_batch(path+'\\'+'data_batch_1')
    data = temp[b'data']
    labels = np.array(temp[b'labels'])
    temp = load_batch(path+'\\'+'data_batch_2')
    data = np.vstack((data,temp[b'data']))
    labels = np.append(labels, temp[b'labels'])
    temp = load_batch(path+'\\'+'data_batch_3')
    data = np.vstack((data,temp[b'data']))
    labels = np.append(labels, temp[b'labels'])
    temp = load_batch(path+'\\'+'data_batch_4')
    data = np.vstack((data,temp[b'data']))
    labels = np.append(labels, temp[b'labels'])
    temp = load_batch(path+'\\'+'data_batch_5')
    data = np.vstack((data,temp[b'data']))
    labels = np.append(labels, temp[b'labels'])    
    return data, labels

def get_cifar10_test(path):
    temp = load_batch(path+'\\'+'test_batch')
    data = temp[b'data']
    labels = np.array(temp[b'labels'])
    return data, labels

# %% [markdown]
# ## Read sample images from CIFAR10

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

X, labels = get_cifar10_train('cifar-10-batches-py')
print(X.shape)
print(X.dtype)
print(labels.shape)
print(labels.dtype)

Xte, labelste = get_cifar10_test('cifar-10-batches-py')
print(Xte.shape)
print(Xte.dtype)
print(labelste.shape)
print(labelste.dtype)

##display the first of the train images
im = X[0,:] 
print(im.shape)
im = np.dstack((im[:1024].reshape((32,32)),im[1024:2048].reshape((32,32)),im[2048:].reshape((32,32))))
print(im.shape)
#print(im)
plt.imshow(im)



#generate a display of several first images
rows = 12
cols = 20
counter = 0

images = None

for i in range(rows):
    current_row = None
    for j in range(cols):
        im = X[counter,:]
        im = np.dstack((im[:1024].reshape((32,32)),im[1024:2048].reshape((32,32)),im[2048:].reshape((32,32))))
        counter = counter + 1
        if current_row is None:
            current_row = im
        else:
            current_row = np.hstack((current_row, im))
    if images is None:
        images = current_row
    else:
        images = np.vstack((images, current_row))
        
plt.figure()
plt.imshow(images)

plt.show()
# Out:
# (50000, 3072)
# uint8
# (50000,)
# int32
# (10000, 3072)
# uint8
# (10000,)
# int32
# (3072,)
# (32, 32, 3)

# %% [markdown]
# ## Example training with linear SoftMax

# %%
import numpy as np
import matplotlib.pyplot as plt


class SoftMaxLinear:
    def __init__(self, inputs_num, outputs_num):
        self.inum = inputs_num
        self.onum = outputs_num
        self.W = (-1 + 2*np.random.rand(inputs_num, outputs_num))/100.0 #neurons as columns
        self.b = np.zeros((1, outputs_num)) #horizontal vector
        self.probs = None
    def Forward(self, X): #examples as rows in X
        f = np.dot(X, self.W) + self.b
        f -= np.max(f, axis=1, keepdims=True) #trick for numerical stability
        probs = np.exp(f)
        probs /= np.sum(probs, axis=1, keepdims=True)
        self.probs = probs
    def Test(self, X, ClsIndx):
        self.Forward(X)
        #data loss: mean cross-entropy loss
        ex_num = X.shape[0]
        data_loss = -np.log(self.probs[range(ex_num),ClsIndx]).sum()/ex_num
        #classification error
        predictions = np.argmax(self.probs, axis=1)
        errors_num = np.sum(predictions != ClsIndx)
        error_rate = errors_num / ex_num
        return (data_loss, error_rate, errors_num)
    def GetProbs(self):
        return self.probs
    def GetPredictions(self):
        return np.argmax(self.probs, axis=1)
    def Learn(self, X, ClsIndx, lrate):
        self.Forward(X)
        #gradients of outputs (class probabilities)
        ex_num = X.shape[0]
        dprobs = self.probs.copy()
        dprobs[range(ex_num), ClsIndx] -= 1.0
        dprobs /= ex_num #average over all examples
        #gradient of weights and biases
        dW = np.dot(X.T, dprobs) # chain rule to calculate gradients
        db = np.sum(dprobs, axis=0,keepdims=True)
        #update neurons
        self.W = self.W - lrate*dW
        self.b = self.b - lrate*db
       
        
        


#train data
print('reading train data...')
X, labels = get_cifar10_train('cifar-10-batches-py')
X = X/255.0 #simple normalization
print(X.shape)
print(X.dtype)
print(labels.shape)
print(labels.dtype)

#test data
print('reading test data...')
Xte, labelste = get_cifar10_test('cifar-10-batches-py')
Xte = Xte/255.0 #simple normalization
print(Xte.shape)
print(Xte.dtype)
print(labelste.shape)
print(labelste.dtype)



net = SoftMaxLinear(3072, 10) #num of inputs = num of pixels; num of outputs = num of classes

#learning statistics
trloss = []
teloss = []
trerate = []
teerate = []
trerrors = []
teerrors = []

#checking the answers before training
(dloss, erate, errors) = net.Test(X, labels)
print('dloss:',dloss)
print('erate:',erate)
print('errors:',errors)
trloss.append(dloss)
trerate.append(erate)
trerrors.append(errors)

(dloss, erate, errors) = net.Test(Xte, labelste)
print('test dloss:',dloss)
print('test erate:',erate)
print('test errors:',errors)
teloss.append(dloss)
teerate.append(erate)
teerrors.append(errors)

print()

print('starting learning...')
counter = 1
max_iters = 100
min_loss = 0.1
while True:
    net.Learn(X, labels, 0.0001)
    (dloss, erate, errors) = net.Test(X, labels)
    print('\niteration', counter)
    print('dloss:',dloss)
    print('erate:',erate)
    print('errors:',errors)
    trloss.append(dloss)
    trerate.append(erate)
    trerrors.append(errors)
    #checking test data
    (dloss, erate, errors) = net.Test(Xte, labelste)
    print('test dloss:',dloss)
    print('test erate:',erate)
    print('test errors:',errors)
    teloss.append(dloss)
    teerate.append(erate)
    teerrors.append(errors)    
    counter += 1
    if dloss < min_loss:
        break
    if counter > max_iters:
        break
print('learning finished')

#save
import pickle
f = open('my_softmax_cifar10.net','wb')
pickle.dump(net, f)
f.close()

print('Minimum training error rate: ', min(trerate),' for iteration ',np.argmin(trerate))
print('Minimum testing error rate: ', min(teerate),' for iteration ',np.argmin(teerate))

plt.figure()
plt.plot(trloss, 'r', label='train')
plt.plot(teloss, 'b', label='test')
plt.title('Loss')
plt.legend()

plt.figure()
plt.plot(trerate, 'r', label='train')
plt.plot(teerate, 'b', label='test')
plt.title('Error rate')

plt.figure()
plt.plot(trerrors, 'r', label='train')
plt.plot(teerrors, 'b', label='test')
plt.title('Errors')

plt.show()
# Out:
# reading train data...
# (50000, 3072)
# float64
# (50000,)
# int32
# reading test data...
# (10000, 3072)
# float64
# (10000,)
# int32
# dloss: 2.326864385417531
# erate: 0.88814
# errors: 44407
# test dloss: 2.3279389390450325
# test erate: 0.8847
# test errors: 8847
#
# starting learning...
#
# iteration 1
# dloss: 2.326453529786637
# erate: 0.88828
# errors: 44414
# test dloss: 2.3275183094739975
# test erate: 0.8847
# test errors: 8847
#
# iteration 2
# dloss: 2.326047305795933
# erate: 0.88844
# errors: 44422
# test dloss: 2.327102418842266
# test erate: 0.8848
# test errors: 8848
#
# iteration 3
# dloss: 2.325645649399245
# erate: 0.88834
# errors: 44417
# test dloss: 2.326691201963082
# test erate: 0.8845
# test errors: 8845
#
# iteration 4
# dloss: 2.325248497426874
# erate: 0.88838
# errors: 44419
# test dloss: 2.3262845945388624
# test erate: 0.8849
# test errors: 8849
#
# iteration 5
# dloss: 2.3248557875739584
# erate: 0.8884
# errors: 44420
# test dloss: 2.3258825331494086
# test erate: 0.8855
# test errors: 8855
#
# iteration 6
# dloss: 2.324467458388972
# erate: 0.88868
# errors: 44434
# test dloss: 2.32548495524026
# test erate: 0.8863
# test errors: 8863
#
# iteration 7
# dloss: 2.3240834492623623
# erate: 0.8886
# errors: 44430
# test dloss: 2.3250917991111923
# test erate: 0.8862
# test errors: 8862
#
# iteration 8
# dloss: 2.323703700415342
# erate: 0.88858
# errors: 44429
# test dloss: 2.3247030039048577
# test erate: 0.8867
# test errors: 8867
#
# iteration 9
# dloss: 2.323328152888806
# erate: 0.88858
# errors: 44429
# test dloss: 2.3243185095955705
# test erate: 0.8865
# test errors: 8865
#
# iteration 10
# dloss: 2.3229567485323983
# erate: 0.88858
# errors: 44429
# test dloss: 2.323938256978228
# test erate: 0.8866
# test errors: 8866
#
# iteration 11
# dloss: 2.3225894299937093
# erate: 0.8889
# errors: 44445
# test dloss: 2.323562187657375
# test erate: 0.8862
# test errors: 8862
#
# iteration 12
# dloss: 2.3222261407076092
# erate: 0.88868
# errors: 44434
# test dloss: 2.323190244036397
# test erate: 0.886
# test errors: 8860
#
# iteration 13
# dloss: 2.3218668248857197
# erate: 0.88868
# errors: 44434
# test dloss: 2.3228223693068624
# test erate: 0.8852
# test errors: 8852
#
# iteration 14
# dloss: 2.3215114275060134
# erate: 0.8888
# errors: 44440
# test dloss: 2.322458507437986
# test erate: 0.8855
# test errors: 8855
#
# iteration 15
# dloss: 2.3211598943025495
# erate: 0.88874
# errors: 44437
# test dloss: 2.3220986031662334
# test erate: 0.8853
# test errors: 8853
#
# iteration 16
# dloss: 2.320812171755334
# erate: 0.889
# errors: 44450
# test dloss: 2.3217426019850564
# test erate: 0.8848
# test errors: 8848
#
# iteration 17
# dloss: 2.320468207080315
# erate: 0.88918
# errors: 44459
# test dloss: 2.3213904501347553
# test erate: 0.8854
# test errors: 8854
#
# iteration 18
# dloss: 2.3201279482194996
# erate: 0.88914
# errors: 44457
# test dloss: 2.3210420945924715
# test erate: 0.8854
# test errors: 8854
#
# iteration 19
# dloss: 2.3197913438312
# erate: 0.88912
# errors: 44456
# test dloss: 2.3206974830623093
# test erate: 0.8856
# test errors: 8856
#
# iteration 20
# dloss: 2.319458343280405
# erate: 0.88896
# errors: 44448
# test dloss: 2.320356563965583
# test erate: 0.8856
# test errors: 8856
#
# iteration 21
# dloss: 2.31912889662927
# erate: 0.88902
# errors: 44451
# test dloss: 2.3200192864311866
# test erate: 0.8859
# test errors: 8859
#
# iteration 22
# dloss: 2.3188029546277353
# erate: 0.88894
# errors: 44447
# test dloss: 2.3196856002860886
# test erate: 0.8858
# test errors: 8858
#
# iteration 23
# dloss: 2.318480468704258
# erate: 0.88896
# errors: 44448
# test dloss: 2.319355456045951
# test erate: 0.8862
# test errors: 8862
#
# iteration 24
# dloss: 2.3181613909566696
# erate: 0.88906
# errors: 44453
# test dloss: 2.319028804905863
# test erate: 0.8858
# test errors: 8858
#
# iteration 25
# dloss: 2.3178456741431477
# erate: 0.88896
# errors: 44448
# test dloss: 2.3187055987312
# test erate: 0.8855
# test errors: 8855
#
# iteration 26
# dloss: 2.317533271673304
# erate: 0.88874
# errors: 44437
# test dloss: 2.3183857900485974
# test erate: 0.8856
# test errors: 8856
#
# iteration 27
# dloss: 2.317224137599389
# erate: 0.88862
# errors: 44431
# test dloss: 2.3180693320370396
# test erate: 0.886
# test errors: 8860
#
# iteration 28
# dloss: 2.316918226607611
# erate: 0.88854
# errors: 44427
# test dloss: 2.317756178519069
# test erate: 0.8857
# test errors: 8857
#
# iteration 29
# dloss: 2.316615494009564
# erate: 0.88836
# errors: 44418
# test dloss: 2.317446283952104
# test erate: 0.8858
# test errors: 8858
#
# iteration 30
# dloss: 2.316315895733773
# erate: 0.88854
# errors: 44427
# test dloss: 2.3171396034198715
# test erate: 0.8856
# test errors: 8856
#
# iteration 31
# dloss: 2.3160193883173417
# erate: 0.8884
# errors: 44420
# test dloss: 2.3168360926239524
# test erate: 0.8853
# test errors: 8853
#
# iteration 32
# dloss: 2.315725928897717
# erate: 0.88844
# errors: 44422
# test dloss: 2.3165357078754343
# test erate: 0.8853
# test errors: 8853
#
# iteration 33
# dloss: 2.3154354752045525
# erate: 0.88856
# errors: 44428
# test dloss: 2.316238406086673
# test erate: 0.8859
# test errors: 8859
#
# iteration 34
# dloss: 2.3151479855516865
# erate: 0.8887
# errors: 44435
# test dloss: 2.3159441447631632
# test erate: 0.8854
# test errors: 8854
#
# iteration 35
# dloss: 2.314863418829219
# erate: 0.88868
# errors: 44434
# test dloss: 2.3156528819955158
# test erate: 0.8852
# test errors: 8852
#
# iteration 36
# dloss: 2.314581734495692
# erate: 0.88884
# errors: 44442
# test dloss: 2.315364576451537
# test erate: 0.8849
# test errors: 8849
#
# iteration 37
# dloss: 2.314302892570377
# erate: 0.88876
# errors: 44438
# test dloss: 2.315079187368412
# test erate: 0.8847
# test errors: 8847
#
# iteration 38
# dloss: 2.31402685362566
# erate: 0.88888
# errors: 44444
# test dloss: 2.3147966745449944
# test erate: 0.8844
# test errors: 8844
#
# iteration 39
# dloss: 2.3137535787795285
# erate: 0.8886
# errors: 44430
# test dloss: 2.3145169983341924
# test erate: 0.8842
# test errors: 8842
#
# iteration 40
# dloss: 2.313483029688154
# erate: 0.88848
# errors: 44424
# test dloss: 2.3142401196354583
# test erate: 0.8848
# test errors: 8848
#
# iteration 41
# dloss: 2.313215168538575
# erate: 0.88858
# errors: 44429
# test dloss: 2.313965999887371
# test erate: 0.8843
# test errors: 8843
#
# iteration 42
# dloss: 2.3129499580414765
# erate: 0.88858
# errors: 44429
# test dloss: 2.313694601060326
# test erate: 0.8846
# test errors: 8846
#
# iteration 43
# dloss: 2.3126873614240626
# erate: 0.88848
# errors: 44424
# test dloss: 2.313425885649309
# test erate: 0.8845
# test errors: 8845
#
# iteration 44
# dloss: 2.3124273424230246
# erate: 0.88854
# errors: 44427
# test dloss: 2.313159816666781
# test erate: 0.8844
# test errors: 8844
#
# iteration 45
# dloss: 2.3121698652776015
# erate: 0.88838
# errors: 44419
# test dloss: 2.3128963576356365
# test erate: 0.8843
# test errors: 8843
#
# iteration 46
# dloss: 2.311914894722733
# erate: 0.88848
# errors: 44424
# test dloss: 2.312635472582274
# test erate: 0.8846
# test errors: 8846
#
# iteration 47
# dloss: 2.3116623959822995
# erate: 0.88834
# errors: 44417
# test dloss: 2.312377126029746
# test erate: 0.8849
# test errors: 8849
#
# iteration 48
# dloss: 2.3114123347624607
# erate: 0.888
# errors: 44400
# test dloss: 2.312121282991008
# test erate: 0.8851
# test errors: 8851
#
# iteration 49
# dloss: 2.3111646772450696
# erate: 0.88786
# errors: 44393
# test dloss: 2.3118679089622445
# test erate: 0.8852
# test errors: 8852
#
# iteration 50
# dloss: 2.310919390081182
# erate: 0.88792
# errors: 44396
# test dloss: 2.3116169699163014
# test erate: 0.885
# test errors: 8850
#
# iteration 51
# dloss: 2.310676440384658
# erate: 0.88794
# errors: 44397
# test dloss: 2.3113684322961876
# test erate: 0.885
# test errors: 8850
#
# iteration 52
# dloss: 2.3104357957258284
# erate: 0.88786
# errors: 44393
# test dloss: 2.311122263008672
# test erate: 0.8854
# test errors: 8854
#
# iteration 53
# dloss: 2.3101974241252683
# erate: 0.88796
# errors: 44398
# test dloss: 2.3108784294179685
# test erate: 0.8855
# test errors: 8855
#
# iteration 54
# dloss: 2.3099612940476413
# erate: 0.88796
# errors: 44398
# test dloss: 2.310636899339496
# test erate: 0.8859
# test errors: 8859
#
# iteration 55
# dloss: 2.3097273743956244
# erate: 0.88766
# errors: 44383
# test dloss: 2.3103976410337275
# test erate: 0.8862
# test errors: 8862
#
# iteration 56
# dloss: 2.3094956345039206
# erate: 0.8879
# errors: 44395
# test dloss: 2.3101606232001184
# test erate: 0.886
# test errors: 8860
#
# iteration 57
# dloss: 2.309266044133345
# erate: 0.88796
# errors: 44398
# test dloss: 2.3099258149711197
# test erate: 0.8855
# test errors: 8855
#
# iteration 58
# dloss: 2.3090385734649965
# erate: 0.88766
# errors: 44383
# test dloss: 2.309693185906265
# test erate: 0.8857
# test errors: 8857
#
# iteration 59
# dloss: 2.3088131930945006
# erate: 0.88786
# errors: 44393
# test dloss: 2.309462705986341
# test erate: 0.886
# test errors: 8860
# iteration 60
# dloss: 2.3085898740263326
# erate: 0.88776
# errors: 44388
# test dloss: 2.3092343456076314
# test erate: 0.8859
# test errors: 8859
#
# iteration 61
# dloss: 2.3083685876682165
# erate: 0.88758
# errors: 44379
# test dloss: 2.3090080755762457
# test erate: 0.8859
# test errors: 8859
#
# iteration 62
# dloss: 2.3081493058255997
# erate: 0.8874
# errors: 44370
# test dloss: 2.308783867102512
# test erate: 0.8855
# test errors: 8855
#
# iteration 63
# dloss: 2.307932000696198
# erate: 0.88744
# errors: 44372
# test dloss: 2.3085616917954566
# test erate: 0.8853
# test errors: 8853
#
# iteration 64
# dloss: 2.307716644864617
# erate: 0.88732
# errors: 44366
# test dloss: 2.308341521657349
# test erate: 0.8853
# test errors: 8853
#
# iteration 65
# dloss: 2.307503211297047
# erate: 0.88738
# errors: 44369
# test dloss: 2.308123329078321
# test erate: 0.8852
# test errors: 8852
#
# iteration 66
# dloss: 2.307291673336023
# erate: 0.88734
# errors: 44367
# test dloss: 2.307907086831067
# test erate: 0.8851
# test errors: 8851
#
# iteration 67
# dloss: 2.3070820046952627
# erate: 0.88714
# errors: 44357
# test dloss: 2.3076927680656
# test erate: 0.8852
# test errors: 8852
#
# iteration 68
# dloss: 2.306874179454566
# erate: 0.88712
# errors: 44356
# test dloss: 2.307480346304089
# test erate: 0.8855
# test errors: 8855
#
# iteration 69
# dloss: 2.3066681720547897
# erate: 0.88696
# errors: 44348
# test dloss: 2.307269795435764
# test erate: 0.8847
# test errors: 8847
#
# iteration 70
# dloss: 2.306463957292885
# erate: 0.88654
# errors: 44327
# test dloss: 2.3070610897118864
# test erate: 0.8847
# test errors: 8847
#
# iteration 71
# dloss: 2.3062615103170057
# erate: 0.88654
# errors: 44327
# test dloss: 2.3068542037407873
# test erate: 0.8841
# test errors: 8841
#
# iteration 72
# dloss: 2.306060806621679
# erate: 0.8865
# errors: 44325
# test dloss: 2.3066491124829778
# test erate: 0.8841
# test errors: 8841
#
# iteration 73
# dloss: 2.3058618220430414
# erate: 0.88636
# errors: 44318
# test dloss: 2.3064457912463134
# test erate: 0.8837
# test errors: 8837
#
# iteration 74
# dloss: 2.3056645327541423
# erate: 0.88626
# errors: 44313
# test dloss: 2.30624421568124
# test erate: 0.8834
# test errors: 8834
#
# iteration 75
# dloss: 2.305468915260307
# erate: 0.88626
# errors: 44313
# test dloss: 2.3060443617760864
# test erate: 0.8832
# test errors: 8832
#
# iteration 76
# dloss: 2.3052749463945625
# erate: 0.88658
# errors: 44329
# test dloss: 2.3058462058524323
# test erate: 0.8827
# test errors: 8827
#
# iteration 77
# dloss: 2.3050826033131284
# erate: 0.88636
# errors: 44318
# test dloss: 2.3056497245605367
# test erate: 0.8835
# test errors: 8835
#
# iteration 78
# dloss: 2.304891863490965
# erate: 0.88632
# errors: 44316
# test dloss: 2.305454894874819
# test erate: 0.8834
# test errors: 8834
#
# iteration 79
# dloss: 2.304702704717383
# erate: 0.88636
# errors: 44318
# test dloss: 2.3052616940894173
# test erate: 0.8836
# test errors: 8836
#
# iteration 80
# dloss: 2.3045151050917125
# erate: 0.88642
# errors: 44321
# test dloss: 2.3050700998137885
# test erate: 0.8832
# test errors: 8832
#
# iteration 81
# dloss: 2.30432904301903
# erate: 0.8865
# errors: 44325
# test dloss: 2.304880089968381
# test erate: 0.8837
# test errors: 8837
#
# iteration 82
# dloss: 2.3041444972059453
# erate: 0.88638
# errors: 44319
# test dloss: 2.3046916427803623
# test erate: 0.8836
# test errors: 8836
#
# iteration 83
# dloss: 2.30396144665644
# erate: 0.88614
# errors: 44307
# test dloss: 2.3045047367793976
# test erate: 0.8835
# test errors: 8835
#
# iteration 84
# dloss: 2.3037798706677703
# erate: 0.88586
# errors: 44293
# test dloss: 2.3043193507934983
# test erate: 0.8835
# test errors: 8835
#
# iteration 85
# dloss: 2.303599748826416
# erate: 0.88538
# errors: 44269
# test dloss: 2.3041354639449128
# test erate: 0.8831
# test errors: 8831
#
# iteration 86
# dloss: 2.3034210610040957
# erate: 0.88526
# errors: 44263
# test dloss: 2.3039530556460837
# test erate: 0.8833
# test errors: 8833
#
# iteration 87
# dloss: 2.303243787353821
# erate: 0.88526
# errors: 44263
# test dloss: 2.3037721055956526
# test erate: 0.8837
# test errors: 8837
#
# iteration 88
# dloss: 2.303067908306021
# erate: 0.88532
# errors: 44266
# test dloss: 2.303592593774522
# test erate: 0.8843
# test errors: 8843
#
# iteration 89
# dloss: 2.3028934045647054
# erate: 0.88482
# errors: 44241
# test dloss: 2.303414500441973
# test erate: 0.8844
# test errors: 8844
#
# iteration 90
# dloss: 2.302720257103688
# erate: 0.88436
# errors: 44218
# test dloss: 2.3032378061318277
# test erate: 0.8845
# test errors: 8845
#
# iteration 91
# dloss: 2.3025484471628586
# erate: 0.88404
# errors: 44202
# test dloss: 2.3030624916486735
# test erate: 0.884
# test errors: 8840
#
# iteration 92
# dloss: 2.302377956244502
# erate: 0.88374
# errors: 44187
# test dloss: 2.3028885380641273
# test erate: 0.8827
# test errors: 8827
#
# iteration 93
# dloss: 2.3022087661096764
# erate: 0.88358
# errors: 44179
# test dloss: 2.3027159267131645
# test erate: 0.8829
# test errors: 8829
#
# iteration 94
# dloss: 2.302040858774632
# erate: 0.88348
# errors: 44174
# test dloss: 2.3025446391904834
# test erate: 0.882
# test errors: 8820
#
# iteration 95
# dloss: 2.3018742165072794
# erate: 0.88272
# errors: 44136
# test dloss: 2.302374657346927
# test erate: 0.8823
# test errors: 8823
#
# iteration 96
# dloss: 2.301708821823712
# erate: 0.88244
# errors: 44122
# test dloss: 2.302205963285954
# test erate: 0.882
# test errors: 8820
#
# iteration 97
# dloss: 2.3015446574847696
# erate: 0.88242
# errors: 44121
# test dloss: 2.302038539360152
# test erate: 0.882
# test errors: 8820
#
# iteration 98
# dloss: 2.3013817064926503
# erate: 0.88176
# errors: 44088
# test dloss: 2.3018723681678037
# test erate: 0.8816
# test errors: 8816
#
# iteration 99
# dloss: 2.3012199520875725
# erate: 0.88132
# errors: 44066
# test dloss: 2.3017074325494957
# test erate: 0.8815
# test errors: 8815
#
# iteration 100
# dloss: 2.301059377744474
# erate: 0.8812
# errors: 44060
# test dloss: 2.3015437155847773
# test erate: 0.8807
# test errors: 8807
# learning finished
# Minimum training error rate:  0.8812  for iteration  100
# Minimum testing error rate:  0.8807  for iteration  100

# %% [markdown]
# ## Task 1
#
# - Use MLP and SoftMax with hidden layer(s) to train on CIFAR10, and check how much you can improve over linear SoftMax.
#
# - Does regularization help to improve the test results?
#
# - Prepare a report presenting your results. Send a pdf file with the report. Attach the source codes. Do not attach the databases.
#
# - Send also the saved trained classifiers – check pickle_example to see how to save objects (your nets). Prepare the code to load the saved network and check the test results.

# %% [markdown]
# ### MLP1HL

# %%
import numpy as np

class MLP1HL:
    def __init__(self, inputs_num, outputs_num, hidden_num):
        self.inum = inputs_num
        self.onum = outputs_num
        self.W1 = (-1 + 2*np.random.rand(inputs_num, hidden_num))/np.sqrt(inputs_num) #neurons as columns
        self.b1 = np.zeros((1, hidden_num)) #horizontal vector
        self.W2 = (-1 + 2*np.random.rand(hidden_num, outputs_num))/np.sqrt(hidden_num) #neurons as columns
        self.b2 = np.zeros((1, outputs_num)) #horizontal vector
#        limit1 = 4*np.sqrt(6.0/(inputs_num+hidden_num))
#        self.W1 = -limit1 + 2*limit1*np.random.rand(inputs_num, hidden_num) #neurons as columns        
#        limit2 = 4*np.sqrt(6.0/(hidden_num+outputs_num))
#        self.W2 = -limit2 + 2*limit2*np.random.rand(hidden_num, outputs_num) #neurons as columns
    def Forward(self, X): #examples as rows in X
        self.u = np.dot(X, self.W1) + self.b1
        self.hout = 1.0/(1.0 + np.exp(-self.u))
        self.outs = np.dot(self.hout, self.W2) + self.b2
    def Test(self, X, ClsIndx):
        self.Forward(X)
        #data loss: mean cross-entropy loss
        ex_num = X.shape[0]
        data_loss = -np.log(self.outs[range(ex_num),ClsIndx]).sum()/ex_num
        #classification error
        predictions = np.argmax(self.outs, axis=1)
        errors_num = np.sum(predictions != ClsIndx)
        error_rate = errors_num / ex_num
        return (data_loss, error_rate, errors_num)
    def GetPredictions(self):
        return np.argmax(self.outs, axis=1)
    def GetMSE(self, D):
        self.mse = np.linalg.norm(self.outs - D, axis=1).sum()/D.shape[0]
        return self.mse
    def LearnClassification(self, X, ClsIndx, lrate):
        pass
    def Update(self, X, D, lrate):
        #self.Forward(X)
        #gradients of outputs 
        ex_num = X.shape[0]
        dY = self.outs - D
        dY /= ex_num #average over all examples
        #gradient of weights and biases - output layer
        dW2 = np.dot(self.hout.T, dY) # chain rule to calculate gradients
        db2 = np.sum(dY, axis=0,keepdims=True)
        #update neurons
        self.W2 = self.W2 - lrate*dW2
        self.b2 = self.b2 - lrate*db2
        #gradient of weights and biases - hidden layer
        temp = np.dot(dY, self.W2.T)
        du = self.hout*(1 - self.hout)
        temp = temp * du  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW1 = np.dot(X.T, temp) # chain rule to calculate gradients
        db1 = np.sum(temp, axis=0,keepdims=True)
        #update neurons
        self.W1 = self.W1 - lrate*dW1
        self.b1 = self.b1 - lrate*db1
    def Learn(self, X, D, epochs, lrate):
        self.stats = []
        self.Forward(X)
        for i in range(epochs):
            self.Update(X, D, lrate)
            self.Forward(X)
            self.stats.append(self.GetMSE(D))

#train data
print('reading train data...')
X, labels = get_cifar10_train('cifar-10-batches-py')
X = X/255.0 #simple normalization
print(X.shape)
print(X.dtype)
print(labels.shape)
print(labels.dtype)

#test data
print('reading test data...')
Xte, labelste = get_cifar10_test('cifar-10-batches-py')
Xte = Xte/255.0 #simple normalization
print(Xte.shape)
print(Xte.dtype)
print(labelste.shape)
print(labelste.dtype)



net = MLP1HL(3072, 10, 20) #num of inputs = num of pixels; num of outputs = num of classes

#learning statistics
trloss = []
teloss = []
trerate = []
teerate = []
trerrors = []
teerrors = []

#checking the answers before training
(dloss, erate, errors) = net.Test(X, labels)
print('dloss:',dloss)
print('erate:',erate)
print('errors:',errors)
trloss.append(dloss)
trerate.append(erate)
trerrors.append(errors)

(dloss, erate, errors) = net.Test(Xte, labelste)
print('test dloss:',dloss)
print('test erate:',erate)
print('test errors:',errors)
teloss.append(dloss)
teerate.append(erate)
teerrors.append(errors)

print()

print('starting learning...')
counter = 1
max_iters = 100
min_loss = 0.1
while True:
    net.Learn(X, labels, max_iters, 0.0001)
    (dloss, erate, errors) = net.Test(X, labels)
    print('\niteration', counter)
    print('dloss:',dloss)
    print('erate:',erate)
    print('errors:',errors)
    trloss.append(dloss)
    trerate.append(erate)
    trerrors.append(errors)
    #checking test data
    (dloss, erate, errors) = net.Test(Xte, labelste)
    print('test dloss:',dloss)
    print('test erate:',erate)
    print('test errors:',errors)
    teloss.append(dloss)
    teerate.append(erate)
    teerrors.append(errors)    
    counter += 1
    if dloss < min_loss:
        break
    if counter > max_iters:
        break
print('learning finished')

#save
import pickle
f = open('my_mlp1hl_cifar10.net','wb')
pickle.dump(net, f)
f.close()

print('Minimum training error rate: ', min(trerate),' for iteration ',np.argmin(trerate))
print('Minimum testing error rate: ', min(teerate),' for iteration ',np.argmin(teerate))

plt.figure()
plt.plot(trloss, 'r', label='train')
plt.plot(teloss, 'b', label='test')
plt.title('Loss')
plt.legend()

plt.figure()
plt.plot(trerate, 'r', label='train')
plt.plot(teerate, 'b', label='test')
plt.title('Error rate')

plt.figure()
plt.plot(trerrors, 'r', label='train')
plt.plot(teerrors, 'b', label='test')
plt.title('Errors')

plt.show()
# Out:
# reading train data...
# (50000, 3072)
# float64
# (50000,)
# int32
# reading test data...
# (10000, 3072)
# float64
# (10000,)
# int32
# D:\Users\migue\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in log
# dloss: nan
# erate: 0.9
# errors: 45000
# test dloss: nan
# test erate: 0.9
# test errors: 9000
#
# starting learning...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d31244422609> in <module>
#     117 min_loss = 0.1
#     118 while True:
# --> 119     net.Learn(X, labels, max_iters, 0.0001)
#     120     (dloss, erate, errors) = net.Test(X, labels)
#     121     print('\niteration', counter)
#
# <ipython-input-8-d31244422609> in Learn(self, X, D, epochs, lrate)
#      59         self.Forward(X)
#      60         for i in range(epochs):
# ---> 61             self.Update(X, D, lrate)
#      62             self.Forward(X)
#      63             self.stats.append(self.GetMSE(D))
#
# <ipython-input-8-d31244422609> in Update(self, X, D, lrate)
#      38         #gradients of outputs
#      39         ex_num = X.shape[0]
# ---> 40         dY = self.outs - D
#      41         dY /= ex_num #average over all examples
#      42         #gradient of weights and biases - output layer
#
# ValueError: operands could not be broadcast together with shapes (50000,10) (50000,)

# %% [markdown]
# ### Softmax1HL

# %%
import numpy as np

class SoftMax1HL:
    def __init__(self, inputs_num, outputs_num, hidden_num):
        self.inum = inputs_num
        self.onum = outputs_num
        self.W1 = (-1 + 2*np.random.rand(inputs_num, hidden_num))/np.sqrt(inputs_num) #neurons as columns
        self.b1 = np.zeros((1, hidden_num)) #horizontal vector
        self.W2 = (-1 + 2*np.random.rand(hidden_num, outputs_num))/np.sqrt(hidden_num) #neurons as columns
        self.b2 = np.zeros((1, outputs_num)) #horizontal vector        
        self.probs = None
    def Forward(self, X): #examples as rows in X
        self.u = np.dot(X, self.W1) + self.b1
        self.hout = 1.0/(1.0 + np.exp(-self.u))
        f = np.dot(self.hout, self.W2) + self.b2
        f -= np.max(f, axis=1, keepdims=True) #trick for numerical stability
        probs = np.exp(f)
        probs /= np.sum(probs, axis=1, keepdims=True)
        self.probs = probs
        return self.probs
    def Test(self, X, ClsIndx):
        self.Forward(X)
        #data loss: mean cross-entropy loss
        ex_num = X.shape[0]
        data_loss = -np.log(self.probs[range(ex_num),ClsIndx]).sum()/ex_num
        #classification error
        predictions = np.argmax(self.probs, axis=1)
        errors_num = np.sum(predictions != ClsIndx)
        error_rate = errors_num / ex_num
        return (data_loss, error_rate, errors_num)
    def GetProbs(self):
        return self.probs
    def GetPredictions(self):
        return np.argmax(self.probs, axis=1)
    def Update(self, X, ClsIndx, lrate): 
        #gradients of outputs (class probabilities)
        ex_num = X.shape[0]
        dprobs = self.probs.copy()
        dprobs[range(ex_num), ClsIndx] -= 1.0
        dprobs /= ex_num #average over all examples
        #gradient of weights and biases - output layer
        dW2 = np.dot(self.hout.T, dprobs) # chain rule to calculate gradients
        db2 = np.sum(dprobs, axis=0,keepdims=True)
        #update neurons
        self.W2 = self.W2 - lrate*dW2
        self.b2 = self.b2 - lrate*db2
        #gradient of weights and biases - hidden layer
        temp = np.dot(dprobs, self.W2.T)
        du = self.hout*(1 - self.hout)
        temp = temp * du  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW1 = np.dot(X.T, temp) # chain rule to calculate gradients
        db1 = np.sum(temp, axis=0,keepdims=True)
        #update neurons
        self.W1 = self.W1 - lrate*dW1
        self.b1 = self.b1 - lrate*db1       
    def Learn(self, X, ClsIndx, epochs, lrate):
        self.Forward(X)
        self.stats = []
        for i in range(epochs):
            self.Update(X, ClsIndx, lrate)
#            self.Forward(X) #not needed if self.Test() is called
            self.stats.append(self.Test(X, ClsIndx)[0])
    
#train data
print('reading train data...')
X, labels = get_cifar10_train('cifar-10-batches-py')
X = X/255.0 #simple normalization
print(X.shape)
print(X.dtype)
print(labels.shape)
print(labels.dtype)

#test data
print('reading test data...')
Xte, labelste = get_cifar10_test('cifar-10-batches-py')
Xte = Xte/255.0 #simple normalization
print(Xte.shape)
print(Xte.dtype)
print(labelste.shape)
print(labelste.dtype)



net = SoftMax1HL(3072, 10, 20) #num of inputs = num of pixels; num of outputs = num of classes

#learning statistics
trloss = []
teloss = []
trerate = []
teerate = []
trerrors = []
teerrors = []

#checking the answers before training
(dloss, erate, errors) = net.Test(X, labels)
print('dloss:',dloss)
print('erate:',erate)
print('errors:',errors)
trloss.append(dloss)
trerate.append(erate)
trerrors.append(errors)

(dloss, erate, errors) = net.Test(Xte, labelste)
print('test dloss:',dloss)
print('test erate:',erate)
print('test errors:',errors)
teloss.append(dloss)
teerate.append(erate)
teerrors.append(errors)

print()

print('starting learning...')
counter = 1
max_iters = 100
min_loss = 0.1
while True:
    net.Learn(X, labels, max_iters, 0.0001)
    (dloss, erate, errors) = net.Test(X, labels)
    print('\niteration', counter)
    print('dloss:',dloss)
    print('erate:',erate)
    print('errors:',errors)
    trloss.append(dloss)
    trerate.append(erate)
    trerrors.append(errors)
    #checking test data
    (dloss, erate, errors) = net.Test(Xte, labelste)
    print('test dloss:',dloss)
    print('test erate:',erate)
    print('test errors:',errors)
    teloss.append(dloss)
    teerate.append(erate)
    teerrors.append(errors)    
    counter += 1
    if dloss < min_loss:
        break
    if counter > max_iters:
        break
print('learning finished')

#save
import pickle
f = open('my_softmax1hl_cifar10.net','wb')
pickle.dump(net, f)
f.close()

print('Minimum training error rate: ', min(trerate),' for iteration ',np.argmin(trerate))
print('Minimum testing error rate: ', min(teerate),' for iteration ',np.argmin(teerate))

plt.figure()
plt.plot(trloss, 'r', label='train')
plt.plot(teloss, 'b', label='test')
plt.title('Loss')
plt.legend()

plt.figure()
plt.plot(trerate, 'r', label='train')
plt.plot(teerate, 'b', label='test')
plt.title('Error rate')

plt.figure()
plt.plot(trerrors, 'r', label='train')
plt.plot(teerrors, 'b', label='test')
plt.title('Errors')

plt.show()
# Out:
# reading train data...
# (50000, 3072)
# float64
# (50000,)
# int32
# reading test data...
# (10000, 3072)
# float64
# (10000,)
# int32
# dloss: 2.3326433388582024
# erate: 0.9064
# errors: 45320
# test dloss: 2.33266416607537
# test erate: 0.9061
# test errors: 9061
#
# starting learning...
#
# iteration 1
# dloss: 2.3302100285527705
# erate: 0.90586
# errors: 45293
# test dloss: 2.33023256579944
# test erate: 0.9067
# test errors: 9067
#
# iteration 2
# dloss: 2.3279355903022605
# erate: 0.90582
# errors: 45291
# test dloss: 2.327960344559184
# test erate: 0.907
# test errors: 9070
#
# iteration 3
# dloss: 2.325811473322873
# erate: 0.90576
# errors: 45288
# test dloss: 2.3258388666611767
# test erate: 0.9075
# test errors: 9075
#
# iteration 4
# dloss: 2.32382893400393
# erate: 0.90564
# errors: 45282
# test dloss: 2.3238593107979484
# test erate: 0.9073
# test errors: 9073
#
# iteration 5
# dloss: 2.3219791759664474
# erate: 0.9054
# errors: 45270
# test dloss: 2.322012810331484
# test erate: 0.9066
# test errors: 9066
#
# iteration 6
# dloss: 2.320253478080035
# erate: 0.90506
# errors: 45253
# test dloss: 2.320290581333551
# test erate: 0.9054
# test errors: 9054
#
# iteration 7
# dloss: 2.3186433054808546
# erate: 0.90484
# errors: 45242
# test dloss: 2.3186840334527297
# test erate: 0.9054
# test errors: 9054
#
# iteration 8
# dloss: 2.317140400824451
# erate: 0.90466
# errors: 45233
# test dloss: 2.317184860872373
# test erate: 0.906
# test errors: 9060
#
# iteration 9
# dloss: 2.315736854983217
# erate: 0.90498
# errors: 45249
# test dloss: 2.3157851126015445
# test erate: 0.9048
# test errors: 9048
#
# iteration 10
# dloss: 2.314425157958766
# erate: 0.90486
# errors: 45243
# test dloss: 2.314477242901432
# test erate: 0.9046
# test errors: 9046
#
# iteration 11
# dloss: 2.3131982318559943
# erate: 0.9045
# errors: 45225
# test dloss: 2.313254143724373
# test erate: 0.9043
# test errors: 9043
#
# iteration 12
# dloss: 2.312049448385348
# erate: 0.90402
# errors: 45201
# test dloss: 2.3121091616587406
# test erate: 0.9045
# test errors: 9045
#
# iteration 13
# dloss: 2.310972633603376
# erate: 0.90416
# errors: 45208
# test dloss: 2.3110361021120895
# test erate: 0.9034
# test errors: 9034
#
# iteration 14
# dloss: 2.3099620625695585
# erate: 0.90394
# errors: 45197
# test dloss: 2.310029223427896
# test erate: 0.9033
# test errors: 9033
#
# iteration 15
# dloss: 2.309012446386141
# erate: 0.90378
# errors: 45189
# test dloss: 2.309083223415237
# test erate: 0.9021
# test errors: 9021
#
# iteration 16
# dloss: 2.308118913777983
# erate: 0.90298
# errors: 45149
# test dloss: 2.3081932204566624
# test erate: 0.9022
# test errors: 9022
#
# iteration 17
# dloss: 2.307276989021448
# erate: 0.90236
# errors: 45118
# test dloss: 2.3073547310079587
# test erate: 0.9031
# test errors: 9031
#
# iteration 18
# dloss: 2.3064825676861602
# erate: 0.90244
# errors: 45122
# test dloss: 2.306563644955376
# test erate: 0.9043
# test errors: 9043
#
# iteration 19
# dloss: 2.3057318913356823
# erate: 0.90172
# errors: 45086
# test dloss: 2.305816199975988
# test erate: 0.9047
# test errors: 9047
#
# iteration 20
# dloss: 2.3050215220555543
# erate: 0.90156
# errors: 45078
# test dloss: 2.305108955767701
# test erate: 0.9052
# test errors: 9052
#
# iteration 21
# dloss: 2.30434831744385
# erate: 0.90096
# errors: 45048
# test dloss: 2.304438768781208
# test erate: 0.9064
# test errors: 9064
#
# iteration 22
# dloss: 2.303709406509623
# erate: 0.9005
# errors: 45025
# test dloss: 2.3038027678958057
# test erate: 0.9068
# test errors: 9068
#
# iteration 23
# dloss: 2.303102166774289
# erate: 0.90032
# errors: 45016
# test dloss: 2.3031983313304587
# test erate: 0.9055
# test errors: 9055
#
# iteration 24
# dloss: 2.3025242027548956
# erate: 0.90074
# errors: 45037
# test dloss: 2.3026230649653816
# test erate: 0.9056
# test errors: 9056
#
# iteration 25
# dloss: 2.3019733259207302
# erate: 0.90092
# errors: 45046
# test dloss: 2.3020747821620557
# test erate: 0.906
# test errors: 9060
#
# iteration 26
# dloss: 2.3014475361504827
# erate: 0.90074
# errors: 45037
# test dloss: 2.3015514851055894
# test erate: 0.9061
# test errors: 9061
#
# iteration 27
# dloss: 2.300945004671335
# erate: 0.90088
# errors: 45044
# test dloss: 2.3010513476478067
# test erate: 0.9065
# test errors: 9065
#
# iteration 28
# dloss: 2.300464058429914
# erate: 0.90094
# errors: 45047
# test dloss: 2.3005726995982854
# test erate: 0.9066
# test errors: 9066
#
# iteration 29
# dloss: 2.300003165824504
# erate: 0.901
# errors: 45050
# test dloss: 2.300114012390357
# test erate: 0.9063
# test errors: 9063
#
# iteration 30
# dloss: 2.2995609237156045
# erate: 0.9007
# errors: 45035
# test dloss: 2.299673886037091
# test erate: 0.9061
# test errors: 9061
#
# iteration 31
# dloss: 2.299136045625647
# erate: 0.89992
# errors: 44996
# test dloss: 2.2992510372862345
# test erate: 0.906
# test errors: 9060
#
# iteration 32
# dloss: 2.2987273510366872
# erate: 0.89948
# errors: 44974
# test dloss: 2.298844288881385
# test erate: 0.9058
# test errors: 9058
#
# iteration 33
# dloss: 2.2983337556959853
# erate: 0.89912
# errors: 44956
# test dloss: 2.2984525598379832
# test erate: 0.9042
# test errors: 9042
#
# iteration 34
# dloss: 2.2979542628424796
# erate: 0.89856
# errors: 44928
# test dloss: 2.298074856645968
# test erate: 0.9037
# test errors: 9037
#
# iteration 35
# dloss: 2.2975879552715757
# erate: 0.89808
# errors: 44904
# test dloss: 2.297710265315579
# test erate: 0.9035
# test errors: 9035
#
# iteration 36
# dloss: 2.29723398816086
# erate: 0.8971
# errors: 44855
# test dloss: 2.297357944188086
# test erate: 0.9023
# test errors: 9023
#
# iteration 37
# dloss: 2.296891582584912
# erate: 0.89658
# errors: 44829
# test dloss: 2.297017117438942
# test erate: 0.9016
# test errors: 9016
#
# iteration 38
# dloss: 2.2965600196530573
# erate: 0.8958
# errors: 44790
# test dloss: 2.296687069206621
# test erate: 0.8997
# test errors: 8997
#
# iteration 39
# dloss: 2.2962386352094994
# erate: 0.89394
# errors: 44697
# test dloss: 2.2963671382860893
# test erate: 0.8989
# test errors: 8989
#
# iteration 40
# dloss: 2.2959268150406227
# erate: 0.89262
# errors: 44631
# test dloss: 2.2960567133313208
# test erate: 0.8981
# test errors: 8981
#
# iteration 41
# dloss: 2.2956239905393745
# erate: 0.89126
# errors: 44563
# test dloss: 2.295755228516401
# test erate: 0.8973
# test errors: 8973
#
# iteration 42
# dloss: 2.295329634781375
# erate: 0.89038
# errors: 44519
# test dloss: 2.2954621596095928
# test erate: 0.8973
# test errors: 8973
#
# iteration 43
# dloss: 2.2950432589717886
# erate: 0.889
# errors: 44450
# test dloss: 2.295177020419179
# test erate: 0.895
# test errors: 8950
#
# iteration 44
# dloss: 2.2947644092260577
# erate: 0.88734
# errors: 44367
# test dloss: 2.2948993595739795
# test erate: 0.8934
# test errors: 8934
#
# iteration 45
# dloss: 2.294492663651279
# erate: 0.88554
# errors: 44277
# test dloss: 2.2946287576051407
# test erate: 0.8922
# test errors: 8922
#
# iteration 46
# dloss: 2.294227629698331
# erate: 0.88454
# errors: 44227
# test dloss: 2.2943648242992145
# test erate: 0.8907
# test errors: 8907
#
# iteration 47
# dloss: 2.293968941757943
# erate: 0.88326
# errors: 44163
# test dloss: 2.2941071962955686
# test erate: 0.8895
# test errors: 8895
#
# iteration 48
# dloss: 2.2937162589765876
# erate: 0.88172
# errors: 44086
# test dloss: 2.29385553490394
# test erate: 0.8881
# test errors: 8881
#
# iteration 49
# dloss: 2.2934692632705773
# erate: 0.8803
# errors: 44015
# test dloss: 2.293609524120431
# test erate: 0.8872
# test errors: 8872
#
# iteration 50
# dloss: 2.2932276575189574
# erate: 0.87914
# errors: 43957
# test dloss: 2.2933688688224785
# test erate: 0.8845
# test errors: 8845
#
# iteration 51
# dloss: 2.2929911639177614
# erate: 0.87796
# errors: 43898
# test dloss: 2.2931332931253134
# test erate: 0.8826
# test errors: 8826
#
# iteration 52
# dloss: 2.292759522480004
# erate: 0.87666
# errors: 43833
# test dloss: 2.2929025388842463
# test erate: 0.882
# test errors: 8820
#
# iteration 53
# dloss: 2.29253248966737
# erate: 0.87552
# errors: 43776
# test dloss: 2.292676364328698
# test erate: 0.8799
# test errors: 8799
#
# iteration 54
# dloss: 2.292309837140993
# erate: 0.87386
# errors: 43693
# test dloss: 2.292454542815351
# test erate: 0.8785
# test errors: 8785
#
# iteration 55
# dloss: 2.292091350620003
# erate: 0.8725
# errors: 43625
# test dloss: 2.29223686168907
# test erate: 0.8782
# test errors: 8782
#
# iteration 56
# dloss: 2.291876828837657
# erate: 0.87126
# errors: 43563
# test dloss: 2.2920231212414
# test erate: 0.8768
# test errors: 8768
#
# iteration 57
# dloss: 2.2916660825859143
# erate: 0.87014
# errors: 43507
# test dloss: 2.2918131337574765
# test erate: 0.8758
# test errors: 8758
#
# iteration 58
# dloss: 2.2914589338402127
# erate: 0.86874
# errors: 43437
# test dloss: 2.291606722643104
# test erate: 0.8756
# test errors: 8756
#
# iteration 59
# dloss: 2.291255214957038
# erate: 0.86786
# errors: 43393
# test dloss: 2.2914037216245777
# test erate: 0.8749
# test errors: 8749
# iteration 60
# dloss: 2.2910547679376068
# erate: 0.86674
# errors: 43337
# test dloss: 2.2912039740145804
# test erate: 0.8735
# test errors: 8735
#
# iteration 61
# dloss: 2.290857443751657
# erate: 0.86568
# errors: 43284
# test dloss: 2.291007332038115
# test erate: 0.8725
# test errors: 8725
#
# iteration 62
# dloss: 2.2906631017159005
# erate: 0.86496
# errors: 43248
# test dloss: 2.2908136562130545
# test erate: 0.8705
# test errors: 8705
#
# iteration 63
# dloss: 2.2904716089222608
# erate: 0.86412
# errors: 43206
# test dloss: 2.290622814780409
# test erate: 0.8702
# test errors: 8702
#
# iteration 64
# dloss: 2.290282839711449
# erate: 0.86298
# errors: 43149
# test dloss: 2.2904346831798743
# test erate: 0.8691
# test errors: 8691
#
# iteration 65
# dloss: 2.290096675187909
# erate: 0.86218
# errors: 43109
# test dloss: 2.290249143566675
# test erate: 0.8682
# test errors: 8682
#
# iteration 66
# dloss: 2.2899130027724777
# erate: 0.8615
# errors: 43075
# test dloss: 2.2900660843660847
# test erate: 0.8672
# test errors: 8672
#
# iteration 67
# dloss: 2.289731715789529
# erate: 0.86066
# errors: 43033
# test dloss: 2.289885399862341
# test erate: 0.8665
# test errors: 8665
#
# iteration 68
# dloss: 2.289552713085603
# erate: 0.85994
# errors: 42997
# test dloss: 2.289706989819
# test erate: 0.8655
# test errors: 8655
#
# iteration 69
# dloss: 2.2893758986768495
# erate: 0.85912
# errors: 42956
# test dloss: 2.289530759128042
# test erate: 0.8644
# test errors: 8644
#
# iteration 70
# dloss: 2.2892011814228446
# erate: 0.85818
# errors: 42909
# test dloss: 2.289356617485295
# test erate: 0.864
# test errors: 8640
#
# iteration 71
# dloss: 2.2890284747245735
# erate: 0.85756
# errors: 42878
# test dloss: 2.289184479089957
# test erate: 0.8637
# test errors: 8637
#
# iteration 72
# dloss: 2.2888576962445497
# erate: 0.85696
# errors: 42848
# test dloss: 2.2890142623662135
# test erate: 0.8628
# test errors: 8628
#
# iteration 73
# dloss: 2.288688767647275
# erate: 0.85662
# errors: 42831
# test dloss: 2.2888458897051227
# test erate: 0.8616
# test errors: 8616
#
# iteration 74
# dloss: 2.288521614358339
# erate: 0.85602
# errors: 42801
# test dloss: 2.2886792872251123
# test erate: 0.8612
# test errors: 8612
#
# iteration 75
# dloss: 2.288356165340683
# erate: 0.85544
# errors: 42772
# test dloss: 2.288514384549564
# test erate: 0.8604
# test errors: 8604
#
# iteration 76
# dloss: 2.2881923528866177
# erate: 0.85484
# errors: 42742
# test dloss: 2.288351114600124
# test erate: 0.8594
# test errors: 8594
#
# iteration 77
# dloss: 2.2880301124243534
# erate: 0.85436
# errors: 42718
# test dloss: 2.2881894134044645
# test erate: 0.8587
# test errors: 8587
#
# iteration 78
# dloss: 2.2878693823378957
# erate: 0.85366
# errors: 42683
# test dloss: 2.2880292199173695
# test erate: 0.8585
# test errors: 8585
#
# iteration 79
# dloss: 2.2877101037992458
# erate: 0.8532
# errors: 42660
# test dloss: 2.287870475854085
# test erate: 0.8568
# test errors: 8568
#
# iteration 80
# dloss: 2.2875522206119645
# erate: 0.85264
# errors: 42632
# test dloss: 2.2877131255349847
# test erate: 0.856
# test errors: 8560
#
# iteration 81
# dloss: 2.287395679065214
# erate: 0.85186
# errors: 42593
# test dloss: 2.2875571157406727
# test erate: 0.8559
# test errors: 8559
#
# iteration 82
# dloss: 2.28724042779748
# erate: 0.85116
# errors: 42558
# test dloss: 2.287402395576727
# test erate: 0.855
# test errors: 8550
#
# iteration 83
# dloss: 2.2870864176692343
# erate: 0.85042
# errors: 42521
# test dloss: 2.2872489163473553
# test erate: 0.8539
# test errors: 8539
#
# iteration 84
# dloss: 2.2869336016438826
# erate: 0.84968
# errors: 42484
# test dloss: 2.2870966314372776
# test erate: 0.853
# test errors: 8530
#
# iteration 85
# dloss: 2.286781934676359
# erate: 0.84884
# errors: 42442
# test dloss: 2.2869454962012417
# test erate: 0.8524
# test errors: 8524
#
# iteration 86
# dloss: 2.286631373608817
# erate: 0.84824
# errors: 42412
# test dloss: 2.286795467860589
# test erate: 0.8515
# test errors: 8515
#
# iteration 87
# dloss: 2.286481877072893
# erate: 0.84766
# errors: 42383
# test dloss: 2.286646505406365
# test erate: 0.8507
# test errors: 8507
#
# iteration 88
# dloss: 2.286333405398069
# erate: 0.84692
# errors: 42346
# test dloss: 2.286498569508492
# test erate: 0.8499
# test errors: 8499
#
# iteration 89
# dloss: 2.286185920525684
# erate: 0.84626
# errors: 42313
# test dloss: 2.2863516224305656
# test erate: 0.8499
# test errors: 8499
#
# iteration 90
# dloss: 2.286039385928209
# erate: 0.84572
# errors: 42286
# test dloss: 2.286205627949882
# test erate: 0.8498
# test errors: 8498
#
# iteration 91
# dloss: 2.2858937665334005
# erate: 0.84488
# errors: 42244
# test dloss: 2.286060551282318
# test erate: 0.8491
# test errors: 8491
#
# iteration 92
# dloss: 2.2857490286529893
# erate: 0.8443
# errors: 42215
# test dloss: 2.285916359011713
# test erate: 0.8485
# test errors: 8485
#
# iteration 93
# dloss: 2.2856051399156043
# erate: 0.84384
# errors: 42192
# test dloss: 2.2857730190234697
# test erate: 0.8479
# test errors: 8479
#
# iteration 94
# dloss: 2.285462069203619
# erate: 0.84296
# errors: 42148
# test dloss: 2.2856305004420423
# test erate: 0.8469
# test errors: 8469
#
# iteration 95
# dloss: 2.2853197865936767
# erate: 0.8425
# errors: 42125
# test dloss: 2.2854887735720824
# test erate: 0.847
# test errors: 8470
#
# iteration 96
# dloss: 2.2851782633006157
# erate: 0.8419
# errors: 42095
# test dloss: 2.285347809842969
# test erate: 0.8469
# test errors: 8469
#
# iteration 97
# dloss: 2.2850374716246034
# erate: 0.84128
# errors: 42064
# test dloss: 2.285207581756505
# test erate: 0.8463
# test errors: 8463
#
# iteration 98
# dloss: 2.2848973849012273
# erate: 0.84054
# errors: 42027
# test dloss: 2.2850680628375755
# test erate: 0.8452
# test errors: 8452
#
# iteration 99
# dloss: 2.2847579774543822
# erate: 0.83992
# errors: 41996
# test dloss: 2.284929227587555
# test erate: 0.8452
# test errors: 8452
#
# iteration 100
# dloss: 2.2846192245517445
# erate: 0.83946
# errors: 41973
# test dloss: 2.2847910514403025
# test erate: 0.8447
# test errors: 8447
# learning finished
# Minimum training error rate:  0.83946  for iteration  100
# Minimum testing error rate:  0.8447  for iteration  100

# %% [markdown]
# ### Softmax2HL with Regularization

# %%
import numpy as np

class SoftMax2HL:
    def __init__(self, inputs_num, outputs_num, hidden_num1, hidden_num2):
        self.inum = inputs_num
        self.onum = outputs_num
        self.W1 = (-1 + 2*np.random.rand(inputs_num, hidden_num1))/np.sqrt(inputs_num) #neurons as columns
        self.b1 = np.zeros((1, hidden_num1)) #horizontal vector
        self.W2 = (-1 + 2*np.random.rand(hidden_num1, hidden_num2))/np.sqrt(hidden_num1) #neurons as columns
        self.b2 = np.zeros((1, hidden_num2)) #horizontal vector
        self.W3 = (-1 + 2*np.random.rand(hidden_num2, outputs_num))/np.sqrt(hidden_num2) #neurons as columns
        self.b3 = np.zeros((1, outputs_num)) #horizontal vector
        self.probs = None
    def Forward(self, X): #examples as rows in X
        self.u1 = np.dot(X, self.W1) + self.b1
        self.hout1 = 1.0/(1.0 + np.exp(-self.u1))
        self.u2 = np.dot(self.hout1, self.W2) + self.b2
        self.hout2 = 1.0/(1.0 + np.exp(-self.u2))
        f = np.dot(self.hout2, self.W3) + self.b3
        f -= np.max(f, axis=1, keepdims=True) #trick for numerical stability
        probs = np.exp(f)
        probs /= np.sum(probs, axis=1, keepdims=True)
        self.probs = probs
    def Test(self, X, ClsIndx):
        self.Forward(X)
        #data loss: mean cross-entropy loss
        ex_num = X.shape[0]
        data_loss = -np.log(self.probs[range(ex_num),ClsIndx]).sum()/ex_num
        #classification error
        predictions = np.argmax(self.probs, axis=1)
        errors_num = np.sum(predictions != ClsIndx)
        error_rate = errors_num / ex_num
        return (data_loss, error_rate, errors_num)
    def GetProbs(self):
        return self.probs
    def GetPredictions(self):
        return np.argmax(self.probs, axis=1)
    def Learn(self, X, ClsIndx, lrate):
        self.Forward(X)
        #gradients of outputs (class probabilities)
        ex_num = X.shape[0]
        dprobs = self.probs.copy()
        dprobs[range(ex_num), ClsIndx] -= 1.0
        dprobs /= ex_num #average over all examples
        #gradient of weights and biases - output layer
        dW3 = np.dot(self.hout2.T, dprobs) # chain rule to calculate gradients
        db3 = np.sum(dprobs, axis=0,keepdims=True)
        
        #update neurons - output layer
        lmbda = 0.0001 # regularization parameter
        self.W3 = self.W3 - lrate*dW3 - lmbda*self.W3
        self.b3 = self.b3 - lrate*db3 - lmbda*self.b3
        self.dW3 = dW3
        self.db3 = db3
        
        #gradient of weights and biases - 2 hidden layer
        temp = np.dot(dprobs, self.W3.T)
        du2 = self.hout2*(1 - self.hout2)
        temp = temp * du2  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW2 = np.dot(self.hout1.T, temp) # chain rule to calculate gradients
        db2 = np.sum(temp, axis=0,keepdims=True)
        #update neurons - second hidden layer
        self.W2 = self.W2 - lrate*dW2 - lmbda*self.W2
        self.b2 = self.b2 - lrate*db2 - lmbda*self.b2       
        self.dW2 = dW2
        self.db2 = db2
        
        #gradient of weights and biases - 1 hidden layer
        temp = np.dot(temp, self.W2.T)
        du1 = self.hout1*(1 - self.hout1)
        temp = temp * du1  #note! this is not a matrix multiplication! this is element-wise multiplication
        dW1 = np.dot(X.T, temp) # chain rule to calculate gradients
        db1 = np.sum(temp, axis=0,keepdims=True)
        #update neurons - first hidden layer
        self.W1 = self.W1 - lrate*dW1 - lmbda*self.W1
        self.b1 = self.b1 - lrate*db1 - lmbda*self.b1       
        self.dW1 = dW1
        self.db1 = db1
        
import numpy as np
import matplotlib.pyplot as plt
import math
import pickle       
        


#train data
print('reading train data...')
X, labels = get_cifar10_train('cifar-10-batches-py')
X = X/255.0 #simple normalization
print(X.shape)
print(X.dtype)
print(labels.shape)
print(labels.dtype)

#test data
print('reading test data...')
Xte, labelste = get_cifar10_test('cifar-10-batches-py')
Xte = Xte/255.0 #simple normalization
print(Xte.shape)
print(Xte.dtype)
print(labelste.shape)
print(labelste.dtype)



net = SoftMax2HL(3072, 10, 20, 10) #num of inputs = num of pixels; num of outputs = num of classes

#learning statistics
trloss = []
teloss = []
trerate = []
teerate = []
trerrors = []
teerrors = []

#checking the answers before training
(dloss, erate, errors) = net.Test(X, labels)
print('dloss:',dloss)
print('erate:',erate)
print('errors:',errors)
trloss.append(dloss)
trerate.append(erate)
trerrors.append(errors)

(dloss, erate, errors) = net.Test(Xte, labelste)
print('test dloss:',dloss)
print('test erate:',erate)
print('test errors:',errors)
teloss.append(dloss)
teerate.append(erate)
teerrors.append(errors)

print()

print('starting learning...')
counter = 1
max_iters = 100
min_loss = 0.1
while True:
    net.Learn(X, labels, 0.0001)
    (dloss, erate, errors) = net.Test(X, labels)
    print('\niteration', counter)
    print('dloss:',dloss)
    print('erate:',erate)
    print('errors:',errors)
    trloss.append(dloss)
    trerate.append(erate)
    trerrors.append(errors)
    #checking test data
    (dloss, erate, errors) = net.Test(Xte, labelste)
    print('test dloss:',dloss)
    print('test erate:',erate)
    print('test errors:',errors)
    teloss.append(dloss)
    teerate.append(erate)
    teerrors.append(errors)    
    counter += 1
    if dloss < min_loss:
        break
    if counter > max_iters:
        break
print('learning finished')

#save
import pickle
f = open('my_softmax2hl_cifar10.net','wb')
pickle.dump(net, f)
f.close()

print('Minimum training error rate: ', min(trerate),' for iteration ',np.argmin(trerate))
print('Minimum testing error rate: ', min(teerate),' for iteration ',np.argmin(teerate))

plt.figure()
plt.plot(trloss, 'r', label='train')
plt.plot(teloss, 'b', label='test')
plt.title('Loss')
plt.legend()

plt.figure()
plt.plot(trerate, 'r', label='train')
plt.plot(teerate, 'b', label='test')
plt.title('Error rate')

plt.figure()
plt.plot(trerrors, 'r', label='train')
plt.plot(teerrors, 'b', label='test')
plt.title('Errors')

plt.show()
# Out:
# reading train data...
# (50000, 3072)
# float64
# (50000,)
# int32
# reading test data...
# (10000, 3072)
# float64
# (10000,)
# int32
# dloss: 2.3486216195119174
# erate: 0.9
# errors: 45000
# test dloss: 2.3486474917531557
# test erate: 0.9
# test errors: 9000
#
# starting learning...
#
# iteration 1
# dloss: 2.3486077628003965
# erate: 0.9
# errors: 45000
# test dloss: 2.348633621799071
# test erate: 0.9
# test errors: 9000
#
# iteration 2
# dloss: 2.348593910826923
# erate: 0.9
# errors: 45000
# test dloss: 2.348619756591603
# test erate: 0.9
# test errors: 9000
#
# iteration 3
# dloss: 2.3485800635894916
# erate: 0.9
# errors: 45000
# test dloss: 2.34860589612874
# test erate: 0.9
# test errors: 9000
#
# iteration 4
# dloss: 2.3485662210860982
# erate: 0.9
# errors: 45000
# test dloss: 2.3485920404084735
# test erate: 0.9
# test errors: 9000
#
# iteration 5
# dloss: 2.3485523833147424
# erate: 0.9
# errors: 45000
# test dloss: 2.3485781894287943
# test erate: 0.9
# test errors: 9000
#
# iteration 6
# dloss: 2.348538550273421
# erate: 0.9
# errors: 45000
# test dloss: 2.3485643431876944
# test erate: 0.9
# test errors: 9000
#
# iteration 7
# dloss: 2.348524721960136
# erate: 0.9
# errors: 45000
# test dloss: 2.3485505016831665
# test erate: 0.9
# test errors: 9000
#
# iteration 8
# dloss: 2.348510898372885
# erate: 0.9
# errors: 45000
# test dloss: 2.348536664913206
# test erate: 0.9
# test errors: 9000
#
# iteration 9
# dloss: 2.3484970795096727
# erate: 0.9
# errors: 45000
# test dloss: 2.3485228328758083
# test erate: 0.9
# test errors: 9000
#
# iteration 10
# dloss: 2.348483265368501
# erate: 0.9
# errors: 45000
# test dloss: 2.34850900556897
# test erate: 0.9
# test errors: 9000
#
# iteration 11
# dloss: 2.3484694559473733
# erate: 0.9
# errors: 45000
# test dloss: 2.348495182990689
# test erate: 0.9
# test errors: 9000
#
# iteration 12
# dloss: 2.3484556512442967
# erate: 0.9
# errors: 45000
# test dloss: 2.348481365138964
# test erate: 0.9
# test errors: 9000
#
# iteration 13
# dloss: 2.3484418512572756
# erate: 0.9
# errors: 45000
# test dloss: 2.3484675520117944
# test erate: 0.9
# test errors: 9000
#
# iteration 14
# dloss: 2.348428055984318
# erate: 0.9
# errors: 45000
# test dloss: 2.3484537436071813
# test erate: 0.9
# test errors: 9000
#
# iteration 15
# dloss: 2.348414265423433
# erate: 0.9
# errors: 45000
# test dloss: 2.3484399399231273
# test erate: 0.9
# test errors: 9000
#
# iteration 16
# dloss: 2.3484004795726285
# erate: 0.9
# errors: 45000
# test dloss: 2.348426140957635
# test erate: 0.9
# test errors: 9000
#
# iteration 17
# dloss: 2.348386698429916
# erate: 0.9
# errors: 45000
# test dloss: 2.3484123467087086
# test erate: 0.9
# test errors: 9000
#
# iteration 18
# dloss: 2.3483729219933074
# erate: 0.9
# errors: 45000
# test dloss: 2.3483985571743538
# test erate: 0.9
# test errors: 9000
#
# iteration 19
# dloss: 2.348359150260815
# erate: 0.9
# errors: 45000
# test dloss: 2.348384772352577
# test erate: 0.9
# test errors: 9000
#
# iteration 20
# dloss: 2.348345383230452
# erate: 0.9
# errors: 45000
# test dloss: 2.3483709922413856
# test erate: 0.9
# test errors: 9000
#
# iteration 21
# dloss: 2.3483316209002343
# erate: 0.9
# errors: 45000
# test dloss: 2.3483572168387874
# test erate: 0.9
# test errors: 9000
#
# iteration 22
# dloss: 2.3483178632681776
# erate: 0.9
# errors: 45000
# test dloss: 2.3483434461427932
# test erate: 0.9
# test errors: 9000
#
# iteration 23
# dloss: 2.3483041103322977
# erate: 0.9
# errors: 45000
# test dloss: 2.3483296801514117
# test erate: 0.9
# test errors: 9000
#
# iteration 24
# dloss: 2.3482903620906144
# erate: 0.9
# errors: 45000
# test dloss: 2.348315918862658
# test erate: 0.9
# test errors: 9000
#
# iteration 25
# dloss: 2.348276618541146
# erate: 0.9
# errors: 45000
# test dloss: 2.3483021622745417
# test erate: 0.9
# test errors: 9000
#
# iteration 26
# dloss: 2.3482628796819127
# erate: 0.9
# errors: 45000
# test dloss: 2.3482884103850776
# test erate: 0.9
# test errors: 9000
#
# iteration 27
# dloss: 2.3482491455109358
# erate: 0.9
# errors: 45000
# test dloss: 2.3482746631922815
# test erate: 0.9
# test errors: 9000
#
# iteration 28
# dloss: 2.3482354160262373
# erate: 0.9
# errors: 45000
# test dloss: 2.348260920694169
# test erate: 0.9
# test errors: 9000
#
# iteration 29
# dloss: 2.3482216912258407
# erate: 0.9
# errors: 45000
# test dloss: 2.3482471828887572
# test erate: 0.9
# test errors: 9000
#
# iteration 30
# dloss: 2.3482079711077715
# erate: 0.9
# errors: 45000
# test dloss: 2.3482334497740647
# test erate: 0.9
# test errors: 9000
#
# iteration 31
# dloss: 2.348194255670054
# erate: 0.9
# errors: 45000
# test dloss: 2.3482197213481095
# test erate: 0.9
# test errors: 9000
#
# iteration 32
# dloss: 2.3481805449107145
# erate: 0.9
# errors: 45000
# test dloss: 2.3482059976089134
# test erate: 0.9
# test errors: 9000
#
# iteration 33
# dloss: 2.3481668388277823
# erate: 0.9
# errors: 45000
# test dloss: 2.3481922785544964
# test erate: 0.9
# test errors: 9000
#
# iteration 34
# dloss: 2.3481531374192848
# erate: 0.9
# errors: 45000
# test dloss: 2.348178564182883
# test erate: 0.9
# test errors: 9000
#
# iteration 35
# dloss: 2.348139440683252
# erate: 0.9
# errors: 45000
# test dloss: 2.3481648544920946
# test erate: 0.9
# test errors: 9000
#
# iteration 36
# dloss: 2.348125748617715
# erate: 0.9
# errors: 45000
# test dloss: 2.3481511494801577
# test erate: 0.9
# test errors: 9000
#
# iteration 37
# dloss: 2.3481120612207054
# erate: 0.9
# errors: 45000
# test dloss: 2.3481374491450957
# test erate: 0.9
# test errors: 9000
#
# iteration 38
# dloss: 2.348098378490257
# erate: 0.9
# errors: 45000
# test dloss: 2.348123753484937
# test erate: 0.9
# test errors: 9000
#
# iteration 39
# dloss: 2.348084700424403
# erate: 0.9
# errors: 45000
# test dloss: 2.3481100624977094
# test erate: 0.9
# test errors: 9000
#
# iteration 40
# dloss: 2.3480710270211786
# erate: 0.9
# errors: 45000
# test dloss: 2.3480963761814415
# test erate: 0.9
# test errors: 9000
#
# iteration 41
# dloss: 2.3480573582786204
# erate: 0.9
# errors: 45000
# test dloss: 2.3480826945341633
# test erate: 0.9
# test errors: 9000
#
# iteration 42
# dloss: 2.3480436941947653
# erate: 0.9
# errors: 45000
# test dloss: 2.348069017553905
# test erate: 0.9
# test errors: 9000
#
# iteration 43
# dloss: 2.3480300347676515
# erate: 0.9
# errors: 45000
# test dloss: 2.3480553452387
# test erate: 0.9
# test errors: 9000
#
# iteration 44
# dloss: 2.348016379995318
# erate: 0.9
# errors: 45000
# test dloss: 2.348041677586581
# test erate: 0.9
# test errors: 9000
#
# iteration 45
# dloss: 2.3480027298758057
# erate: 0.9
# errors: 45000
# test dloss: 2.348028014595581
# test erate: 0.9
# test errors: 9000
#
# iteration 46
# dloss: 2.347989084407156
# erate: 0.9
# errors: 45000
# test dloss: 2.348014356263737
# test erate: 0.9
# test errors: 9000
#
# iteration 47
# dloss: 2.347975443587412
# erate: 0.9
# errors: 45000
# test dloss: 2.348000702589084
# test erate: 0.9
# test errors: 9000
#
# iteration 48
# dloss: 2.3479618074146154
# erate: 0.9
# errors: 45000
# test dloss: 2.34798705356966
# test erate: 0.9
# test errors: 9000
#
# iteration 49
# dloss: 2.347948175886813
# erate: 0.9
# errors: 45000
# test dloss: 2.347973409203503
# test erate: 0.9
# test errors: 9000
#
# iteration 50
# dloss: 2.3479345490020487
# erate: 0.9
# errors: 45000
# test dloss: 2.3479597694886536
# test erate: 0.9
# test errors: 9000
#
# iteration 51
# dloss: 2.3479209267583703
# erate: 0.9
# errors: 45000
# test dloss: 2.347946134423151
# test erate: 0.9
# test errors: 9000
#
# iteration 52
# dloss: 2.3479073091538245
# erate: 0.9
# errors: 45000
# test dloss: 2.3479325040050374
# test erate: 0.9
# test errors: 9000
#
# iteration 53
# dloss: 2.347893696186461
# erate: 0.9
# errors: 45000
# test dloss: 2.3479188782323552
# test erate: 0.9
# test errors: 9000
#
# iteration 54
# dloss: 2.34788008785433
# erate: 0.9
# errors: 45000
# test dloss: 2.3479052571031485
# test erate: 0.9
# test errors: 9000
#
# iteration 55
# dloss: 2.3478664841554813
# erate: 0.9
# errors: 45000
# test dloss: 2.3478916406154617
# test erate: 0.9
# test errors: 9000
#
# iteration 56
# dloss: 2.347852885087968
# erate: 0.9
# errors: 45000
# test dloss: 2.3478780287673406
# test erate: 0.9
# test errors: 9000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8b452c739412> in <module>
#     139 min_loss = 0.1
#     140 while True:
# --> 141     net.Learn(X, labels, 0.0001)
#     142     (dloss, erate, errors) = net.Test(X, labels)
#     143     print('\niteration', counter)
#
# <ipython-input-13-8b452c739412> in Learn(self, X, ClsIndx, lrate)
#      37         return np.argmax(self.probs, axis=1)
#      38     def Learn(self, X, ClsIndx, lrate):
# ---> 39         self.Forward(X)
#      40         #gradients of outputs (class probabilities)
#      41         ex_num = X.shape[0]
#
# <ipython-input-13-8b452c739412> in Forward(self, X)
#      14     def Forward(self, X): #examples as rows in X
#      15         self.u1 = np.dot(X, self.W1) + self.b1
# ---> 16         self.hout1 = 1.0/(1.0 + np.exp(-self.u1))
#      17         self.u2 = np.dot(self.hout1, self.W2) + self.b2
#      18         self.hout2 = 1.0/(1.0 + np.exp(-self.u2))
#
# KeyboardInterrupt:
